# %%
import pandas as pd

# %%
annual_gas_data = pd.read_csv('Resources/Datasets/cleaned_data/Annual_us_gas_data.csv')
consumer_factors = pd.read_csv('Resources/Datasets/cleaned_data/consumer_factors.csv')

annual_gas_data
# Out:
#     Year  avg_production(Mmcf)  avg_consumption(Mmcf)  avg_vol(Mmcf)  \
# 0   2001          1.714191e+06           1.853219e+06   6.335558e+06
# 1   2002          1.657065e+06           1.918918e+06   6.715545e+06
# 2   2003          1.664530e+06           1.856375e+06   6.256805e+06
# 3   2004          1.626458e+06           1.866879e+06   6.460054e+06
# 4   2005          1.577258e+06           1.834536e+06   6.492884e+06
# 5   2006          1.617473e+06           1.808256e+06   6.860307e+06
# 6   2007          1.683029e+06           1.925316e+06   6.837505e+06
# 7   2008          1.759338e+06           1.939751e+06   6.592182e+06
# 8   2009          1.803995e+06           1.909173e+06   7.052343e+06
# 9   2010          1.865156e+06           2.007233e+06   7.052461e+06
# 10  2011          2.003029e+06           2.039785e+06   7.004209e+06
# 11  2012          2.106940e+06           2.128207e+06   7.501633e+06
# 12  2013          2.130186e+06           2.179589e+06   7.149331e+06
# 13  2014          2.291480e+06           2.216115e+06   6.620863e+06
# 14  2015          2.397670e+06           2.270321e+06   7.171337e+06
# 15  2016          2.366671e+06           2.287018e+06   7.577976e+06
# 16  2017          2.436486e+06           2.261873e+06   7.304990e+06
# 17  2018          2.750739e+06           2.511578e+06   6.654810e+06
# 18  2019          3.037243e+06           2.594337e+06   6.901474e+06
# 19  2020          3.016870e+06           2.539351e+06   7.456273e+06
# 20  2021          3.084288e+06           2.523619e+06   7.134772e+06
# 21  2022          3.018587e+06           3.315793e+06   6.325246e+06
#
#     avg_total_import(Mmcf)  avg_toal_export(Mmcf)  avg_import_price($/Mmcf)  \
# 0            331411.500000           31106.583333                  4.357500
# 1            334622.000000           43019.333333                  3.138333
# 2            328645.750000           56660.250000                  5.180833
# 3            354879.916667           71178.083333                  5.779167
# 4            361752.833333           60716.666667                  8.085000
# 5            348856.833333           60329.750000                  6.866667
# 6            383965.166667           68537.833333                  6.872500
# 7            332008.416667           80271.750000                  8.774167
# 8            312613.333333           89363.083333                  4.136667
# 9            311730.000000           94732.416667                  4.464167
# 10           289057.750000          125470.833333                  4.221667
# 11           261482.416667          134902.333333                  2.880833
# 12           240279.666667          131034.416667                  3.815000
# 13           224614.916667          126186.833333                  5.380833
# 14           226507.750000          148626.083333                  3.153333
# 15           250536.500000          194620.666667                  2.337500
# 16           252768.916667          262817.000000                  2.690000
# 17           240737.000000          300653.500000                  2.812500
# 18           228476.333333          388138.083333                  2.588333
# 19           212611.666667          440300.666667                  2.086667
# 20           233996.833333          554384.000000                  3.735833
# 21           277784.000000          577832.500000                  6.245000
#
#     avg_export_price($/Mmcf)  avg_all_grades_p($/Gallon)  avg_reg_p($/Gallon)  \
# 0                   4.383333                    1.466167             1.426000
# 1                   3.339167                    1.381833             1.340333
# 2                   5.582500                    1.601083             1.559167
# 3                   6.069167                    1.891250             1.848750
# 4                   8.010833                    2.312167             2.268167
# 5                   6.831667                    2.615083             2.569167
# 6                   6.905833                    2.845500             2.798583
# 7                   8.774167                    3.305083             3.251833
# 8                   4.354167                    2.396667             2.343500
# 9                   5.030000                    2.833583             2.780333
# 10                  4.640833                    3.576417             3.520917
# 11                  3.223333                    3.686167             3.625000
# 12                  4.081667                    3.576417             3.505917
# 13                  5.410000                    3.442000             3.363167
# 14                  3.080000                    2.513000             2.422167
# 15                  2.745833                    2.252500             2.145833
# 16                  3.535833                    2.530333             2.417000
# 17                  3.855833                    2.817333             2.723000
# 18                  3.630833                    2.685750             2.598250
# 19                  3.624167                    2.259750             2.168833
# 20                  6.512500                    3.093750             3.001167
# 21                  7.630000                    3.512000             3.416000
#
#     avg_midg_p($/Gallon)  avg_pre_p($/Gallon)  avg_dis_p($/Gallon)
# 0               1.518833             1.607917             1.404083
# 1               1.435250             1.525833             1.315333
# 2               1.656333             1.746000             1.508333
# 3               1.946917             2.038417             1.807500
# 4               2.367583             2.465917             2.398667
# 5               2.673000             2.775917             2.705000
# 6               2.905667             3.009500             2.881667
# 7               3.372917             3.491750             3.806833
# 8               2.464500             2.581250             2.463667
# 9               2.900917             3.020083             2.989333
# 10              3.644167             3.771000             3.845333
# 11              3.762000             3.900250             3.970417
# 12              3.663167             3.822917             3.922917
# 13              3.544833             3.715750             3.828667
# 14              2.638167             2.823333             2.706583
# 15              2.397000             2.618167             2.306167
# 16              2.684083             2.918917             2.653667
# 17              3.059500             3.298250             3.178833
# 18              2.994250             3.246333             3.055583
# 19              2.584250             2.835333             2.555250
# 20              3.425583             3.680000             3.280583
# 21              3.852500             4.123000             3.878000

# %%
annual_gas_data = annual_gas_data[(annual_gas_data.Year <= int(2021))]
annual_gas_data.columns
# Out:
# Index(['Year', 'avg_production(Mmcf)', 'avg_consumption(Mmcf)',
#        'avg_vol(Mmcf)', 'avg_total_import(Mmcf)', 'avg_toal_export(Mmcf)',
#        'avg_import_price($/Mmcf)', 'avg_export_price($/Mmcf)',
#        'avg_all_grades_p($/Gallon)', 'avg_reg_p($/Gallon)',
#        'avg_midg_p($/Gallon)', 'avg_pre_p($/Gallon)', 'avg_dis_p($/Gallon)'],
#       dtype='object')

# %%
consumer_factors.head()
# Out:
#    Year  all_conusmers(Mmcf)  commercial_consumers(Mmcf)  \
# 0  2021             27437503                     3263722
# 1  2020             27660375                     3170221
# 2  2019             28291006                     3514566
# 3  2018             27568157                     3513954
# 4  2017             24834715                     3164615
#
#    electric_consumers(Mmcf)  industrial_consumers(Mmcf)  \
# 0                  11270552                     8196569
# 1                  11615988                     8150724
# 2                  11288096                     8416660
# 3                  10588937                     8417300
# 4                   9265555                     7943018
#
#    residential_consumers(Mmcf)  vehicle_consumers(Mmcf)
# 0                      4653503                    53157
# 1                      4674311                    49130
# 2                      5018519                    53166
# 3                      4997554                    50413
# 4                      4413324                    48204

# %%
consumer_factors = consumer_factors.sort_values(by= 'Year')
consumer_factors
# Out:
#     Year  all_conusmers(Mmcf)  commercial_consumers(Mmcf)  \
# 20  2001             20495108                     3022712
# 19  2002             21247016                     3144170
# 18  2003             20562727                     3179493
# 17  2004             20738454                     3128972
# 16  2005             20318892                     2998920
# 15  2006             19972881                     2832030
# 14  2007             21256042                     3012904
# 13  2008             21409349                     3152529
# 12  2009             20964665                     3118592
# 11  2010             22127046                     3102593
# 10  2011             22467053                     3155319
# 9   2012             23411423                     2894926
# 8   2013             23838925                     3295301
# 7   2014             24381082                     3466308
# 6   2015             24989285                     3201734
# 5   2016             25212159                     3109584
# 4   2017             24834715                     3164615
# 3   2018             27568157                     3513954
# 2   2019             28291006                     3514566
# 1   2020             27660375                     3170221
# 0   2021             27437503                     3263722
#
#     electric_consumers(Mmcf)  industrial_consumers(Mmcf)  \
# 20                   5342301                     7344219
# 19                   5671897                     7527184
# 18                   5135215                     7150396
# 17                   5463763                     7256408
# 16                   5869145                     6601168
# 15                   6222100                     6526546
# 14                   6841408                     6654716
# 13                   6668379                     6670182
# 12                   6872533                     6167371
# 11                   7387184                     6826192
# 10                   7573863                     6994120
# 9                    9110793                     7226215
# 8                    8190756                     7425452
# 7                    8145982                     7646039
# 6                    9613370                     7521903
# 5                    9985270                     7728688
# 4                    9265555                     7943018
# 3                   10588937                     8417300
# 2                   11288096                     8416660
# 1                   11615988                     8150724
# 0                   11270552                     8196569
#
#     residential_consumers(Mmcf)  vehicle_consumers(Mmcf)
# 20                      4771340                    14536
# 19                      4888818                    14950
# 18                      5079351                    18271
# 17                      4868797                    20514
# 16                      4826775                    22884
# 15                      4368466                    23739
# 14                      4722358                    24655
# 13                      4892277                    25982
# 12                      4778907                    27262
# 11                      4782412                    28664
# 10                      4713777                    29974
# 9                       4149519                    29970
# 8                       4897372                    30045
# 7                       5087471                    35282
# 6                       4612888                    39390
# 5                       4346588                    42028
# 4                       4413324                    48204
# 3                       4997554                    50413
# 2                       5018519                    53166
# 1                       4674311                    49130
# 0                       4653503                    53157

# %%
consumer_factors.describe()
# Out:
#               Year  all_conusmers(Mmcf)  commercial_consumers(Mmcf)  \
# count    21.000000         2.100000e+01                2.100000e+01
# mean   2011.000000         2.329447e+07                3.163960e+06
# std       6.204837         2.747401e+06                1.773290e+05
# min    2001.000000         1.997288e+07                2.832030e+06
# 25%    2006.000000         2.096466e+07                3.102593e+06
# 50%    2011.000000         2.246705e+07                3.152529e+06
# 75%    2016.000000         2.498928e+07                3.201734e+06
# max    2021.000000         2.829101e+07                3.514566e+06
#
#        electric_consumers(Mmcf)  industrial_consumers(Mmcf)  \
# count              2.100000e+01                2.100000e+01
# mean               8.005861e+06                7.351956e+06
# std                2.127099e+06                6.454454e+05
# min                5.135215e+06                6.167371e+06
# 25%                6.222100e+06                6.826192e+06
# 50%                7.573863e+06                7.344219e+06
# 75%                9.613370e+06                7.728688e+06
# max                1.161599e+07                8.417300e+06
#
#        residential_consumers(Mmcf)  vehicle_consumers(Mmcf)
# count                 2.100000e+01                 21.00000
# mean                  4.740206e+06              32486.47619
# std                   2.505458e+05              12559.62053
# min                   4.149519e+06              14536.00000
# 25%                   4.653503e+06              23739.00000
# 50%                   4.778907e+06              29970.00000
# 75%                   4.892277e+06              42028.00000
# max                   5.087471e+06              53166.00000

# %%
#new df from select factors from us_gas_data
orig_factors = annual_gas_data[['Year', 'avg_production(Mmcf)', 'avg_consumption(Mmcf)',
       'avg_vol(Mmcf)', 'avg_total_import(Mmcf)', 'avg_toal_export(Mmcf)',
       'avg_import_price($/Mmcf)', 'avg_export_price($/Mmcf)',
       'avg_all_grades_p($/Gallon)']]

orig_factors
# Out:
#     Year  avg_production(Mmcf)  avg_consumption(Mmcf)  avg_vol(Mmcf)  \
# 0   2001          1.714191e+06           1.853219e+06   6.335558e+06
# 1   2002          1.657065e+06           1.918918e+06   6.715545e+06
# 2   2003          1.664530e+06           1.856375e+06   6.256805e+06
# 3   2004          1.626458e+06           1.866879e+06   6.460054e+06
# 4   2005          1.577258e+06           1.834536e+06   6.492884e+06
# 5   2006          1.617473e+06           1.808256e+06   6.860307e+06
# 6   2007          1.683029e+06           1.925316e+06   6.837505e+06
# 7   2008          1.759338e+06           1.939751e+06   6.592182e+06
# 8   2009          1.803995e+06           1.909173e+06   7.052343e+06
# 9   2010          1.865156e+06           2.007233e+06   7.052461e+06
# 10  2011          2.003029e+06           2.039785e+06   7.004209e+06
# 11  2012          2.106940e+06           2.128207e+06   7.501633e+06
# 12  2013          2.130186e+06           2.179589e+06   7.149331e+06
# 13  2014          2.291480e+06           2.216115e+06   6.620863e+06
# 14  2015          2.397670e+06           2.270321e+06   7.171337e+06
# 15  2016          2.366671e+06           2.287018e+06   7.577976e+06
# 16  2017          2.436486e+06           2.261873e+06   7.304990e+06
# 17  2018          2.750739e+06           2.511578e+06   6.654810e+06
# 18  2019          3.037243e+06           2.594337e+06   6.901474e+06
# 19  2020          3.016870e+06           2.539351e+06   7.456273e+06
# 20  2021          3.084288e+06           2.523619e+06   7.134772e+06
#
#     avg_total_import(Mmcf)  avg_toal_export(Mmcf)  avg_import_price($/Mmcf)  \
# 0            331411.500000           31106.583333                  4.357500
# 1            334622.000000           43019.333333                  3.138333
# 2            328645.750000           56660.250000                  5.180833
# 3            354879.916667           71178.083333                  5.779167
# 4            361752.833333           60716.666667                  8.085000
# 5            348856.833333           60329.750000                  6.866667
# 6            383965.166667           68537.833333                  6.872500
# 7            332008.416667           80271.750000                  8.774167
# 8            312613.333333           89363.083333                  4.136667
# 9            311730.000000           94732.416667                  4.464167
# 10           289057.750000          125470.833333                  4.221667
# 11           261482.416667          134902.333333                  2.880833
# 12           240279.666667          131034.416667                  3.815000
# 13           224614.916667          126186.833333                  5.380833
# 14           226507.750000          148626.083333                  3.153333
# 15           250536.500000          194620.666667                  2.337500
# 16           252768.916667          262817.000000                  2.690000
# 17           240737.000000          300653.500000                  2.812500
# 18           228476.333333          388138.083333                  2.588333
# 19           212611.666667          440300.666667                  2.086667
# 20           233996.833333          554384.000000                  3.735833
#
#     avg_export_price($/Mmcf)  avg_all_grades_p($/Gallon)
# 0                   4.383333                    1.466167
# 1                   3.339167                    1.381833
# 2                   5.582500                    1.601083
# 3                   6.069167                    1.891250
# 4                   8.010833                    2.312167
# 5                   6.831667                    2.615083
# 6                   6.905833                    2.845500
# 7                   8.774167                    3.305083
# 8                   4.354167                    2.396667
# 9                   5.030000                    2.833583
# 10                  4.640833                    3.576417
# 11                  3.223333                    3.686167
# 12                  4.081667                    3.576417
# 13                  5.410000                    3.442000
# 14                  3.080000                    2.513000
# 15                  2.745833                    2.252500
# 16                  3.535833                    2.530333
# 17                  3.855833                    2.817333
# 18                  3.630833                    2.685750
# 19                  3.624167                    2.259750
# 20                  6.512500                    3.093750

# %%
##Merge dataframe
new_factors = orig_factors.merge(consumer_factors, on='Year')
new_factors
# Out:
#     Year  avg_production(Mmcf)  avg_consumption(Mmcf)  avg_vol(Mmcf)  \
# 0   2001          1.714191e+06           1.853219e+06   6.335558e+06
# 1   2002          1.657065e+06           1.918918e+06   6.715545e+06
# 2   2003          1.664530e+06           1.856375e+06   6.256805e+06
# 3   2004          1.626458e+06           1.866879e+06   6.460054e+06
# 4   2005          1.577258e+06           1.834536e+06   6.492884e+06
# 5   2006          1.617473e+06           1.808256e+06   6.860307e+06
# 6   2007          1.683029e+06           1.925316e+06   6.837505e+06
# 7   2008          1.759338e+06           1.939751e+06   6.592182e+06
# 8   2009          1.803995e+06           1.909173e+06   7.052343e+06
# 9   2010          1.865156e+06           2.007233e+06   7.052461e+06
# 10  2011          2.003029e+06           2.039785e+06   7.004209e+06
# 11  2012          2.106940e+06           2.128207e+06   7.501633e+06
# 12  2013          2.130186e+06           2.179589e+06   7.149331e+06
# 13  2014          2.291480e+06           2.216115e+06   6.620863e+06
# 14  2015          2.397670e+06           2.270321e+06   7.171337e+06
# 15  2016          2.366671e+06           2.287018e+06   7.577976e+06
# 16  2017          2.436486e+06           2.261873e+06   7.304990e+06
# 17  2018          2.750739e+06           2.511578e+06   6.654810e+06
# 18  2019          3.037243e+06           2.594337e+06   6.901474e+06
# 19  2020          3.016870e+06           2.539351e+06   7.456273e+06
# 20  2021          3.084288e+06           2.523619e+06   7.134772e+06
#
#     avg_total_import(Mmcf)  avg_toal_export(Mmcf)  avg_import_price($/Mmcf)  \
# 0            331411.500000           31106.583333                  4.357500
# 1            334622.000000           43019.333333                  3.138333
# 2            328645.750000           56660.250000                  5.180833
# 3            354879.916667           71178.083333                  5.779167
# 4            361752.833333           60716.666667                  8.085000
# 5            348856.833333           60329.750000                  6.866667
# 6            383965.166667           68537.833333                  6.872500
# 7            332008.416667           80271.750000                  8.774167
# 8            312613.333333           89363.083333                  4.136667
# 9            311730.000000           94732.416667                  4.464167
# 10           289057.750000          125470.833333                  4.221667
# 11           261482.416667          134902.333333                  2.880833
# 12           240279.666667          131034.416667                  3.815000
# 13           224614.916667          126186.833333                  5.380833
# 14           226507.750000          148626.083333                  3.153333
# 15           250536.500000          194620.666667                  2.337500
# 16           252768.916667          262817.000000                  2.690000
# 17           240737.000000          300653.500000                  2.812500
# 18           228476.333333          388138.083333                  2.588333
# 19           212611.666667          440300.666667                  2.086667
# 20           233996.833333          554384.000000                  3.735833
#
#     avg_export_price($/Mmcf)  avg_all_grades_p($/Gallon)  all_conusmers(Mmcf)  \
# 0                   4.383333                    1.466167             20495108
# 1                   3.339167                    1.381833             21247016
# 2                   5.582500                    1.601083             20562727
# 3                   6.069167                    1.891250             20738454
# 4                   8.010833                    2.312167             20318892
# 5                   6.831667                    2.615083             19972881
# 6                   6.905833                    2.845500             21256042
# 7                   8.774167                    3.305083             21409349
# 8                   4.354167                    2.396667             20964665
# 9                   5.030000                    2.833583             22127046
# 10                  4.640833                    3.576417             22467053
# 11                  3.223333                    3.686167             23411423
# 12                  4.081667                    3.576417             23838925
# 13                  5.410000                    3.442000             24381082
# 14                  3.080000                    2.513000             24989285
# 15                  2.745833                    2.252500             25212159
# 16                  3.535833                    2.530333             24834715
# 17                  3.855833                    2.817333             27568157
# 18                  3.630833                    2.685750             28291006
# 19                  3.624167                    2.259750             27660375
# 20                  6.512500                    3.093750             27437503
#
#     commercial_consumers(Mmcf)  electric_consumers(Mmcf)  \
# 0                      3022712                   5342301
# 1                      3144170                   5671897
# 2                      3179493                   5135215
# 3                      3128972                   5463763
# 4                      2998920                   5869145
# 5                      2832030                   6222100
# 6                      3012904                   6841408
# 7                      3152529                   6668379
# 8                      3118592                   6872533
# 9                      3102593                   7387184
# 10                     3155319                   7573863
# 11                     2894926                   9110793
# 12                     3295301                   8190756
# 13                     3466308                   8145982
# 14                     3201734                   9613370
# 15                     3109584                   9985270
# 16                     3164615                   9265555
# 17                     3513954                  10588937
# 18                     3514566                  11288096
# 19                     3170221                  11615988
# 20                     3263722                  11270552
#
#     industrial_consumers(Mmcf)  residential_consumers(Mmcf)  \
# 0                      7344219                      4771340
# 1                      7527184                      4888818
# 2                      7150396                      5079351
# 3                      7256408                      4868797
# 4                      6601168                      4826775
# 5                      6526546                      4368466
# 6                      6654716                      4722358
# 7                      6670182                      4892277
# 8                      6167371                      4778907
# 9                      6826192                      4782412
# 10                     6994120                      4713777
# 11                     7226215                      4149519
# 12                     7425452                      4897372
# 13                     7646039                      5087471
# 14                     7521903                      4612888
# 15                     7728688                      4346588
# 16                     7943018                      4413324
# 17                     8417300                      4997554
# 18                     8416660                      5018519
# 19                     8150724                      4674311
# 20                     8196569                      4653503
#
#     vehicle_consumers(Mmcf)
# 0                     14536
# 1                     14950
# 2                     18271
# 3                     20514
# 4                     22884
# 5                     23739
# 6                     24655
# 7                     25982
# 8                     27262
# 9                     28664
# 10                    29974
# 11                    29970
# 12                    30045
# 13                    35282
# 14                    39390
# 15                    42028
# 16                    48204
# 17                    50413
# 18                    53166
# 19                    49130
# 20                    53157

# %% [markdown]
# ## Supervised ML

# %%
#initialize X, y
X = new_factors.drop(columns = ['avg_all_grades_p($/Gallon)'])
y = new_factors['avg_all_grades_p($/Gallon)']

# %%
#Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#Scale data
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()
X_train_s = data_scaler.fit_transform(X_train)
X_test_s = data_scaler.fit_transform(X_test)

# %%
#create instance of model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#train the model
model.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
#create prediction to test
y_pred = model.predict(X_test_s)
y_pred
# Out:
# array([ 1.38415919e+08,  2.88600663e+06, -9.22276987e+07,  1.56770096e+08,
#        -1.43612426e+08, -6.22318797e+07])

# %%
#results
print('Multi-Linear_Regression Model Result:')
print(y_pred.shape)
print('---------------------------------------')
print('intercept: \n', model.intercept_)
print('Coefficients: \n', model.coef_)
# Out:
# Multi-Linear_Regression Model Result:
# (6,)
# ---------------------------------------
# intercept:
#  2.810151543882386
# Coefficients:
#  [-1.14851316e+03 -1.29597427e+04  5.04245851e+03 -1.11357300e+03
#  -1.82884770e+03  8.57764543e+03  5.25699415e+03 -5.53480229e+03
#   2.73482512e+09 -1.66250316e+08 -2.16351744e+09 -6.09324390e+08
#  -2.55397570e+08 -1.22012755e+07]

# %% [markdown]
# ####  Regression metrics

# %%
import sklearn.metrics as skm
print('MAE =', round(skm.mean_absolute_error(y_test, y_pred), 2))
print("MSE =", round(skm.mean_squared_error(y_test, y_pred), 2)) 
print("MAE =", round(skm.median_absolute_error(y_test, y_pred), 2)) 
print("EVS =", round(skm.explained_variance_score(y_test, y_pred), 2)) 
print("R2 score =", round(skm.r2_score(y_test, y_pred), 2))
# Out:
# MAE = 99357337.99
# MSE = 1.279124058119427e+16
# MAE = 115321809.17
# EVS = -4.28625165216735e+16
# R2 score = -4.28625165216735e+16

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X)
# Out:
# C:\Users\Phoeb\anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
sm_model = sm.OLS(y, X).fit()

# %%
predictions = sm_model.predict(X)

# %%
print(sm_model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     avg_all_grades_p($/Gallon)   R-squared:                       0.912
# Model:                                    OLS   Adj. R-squared:                  0.708
# Method:                         Least Squares   F-statistic:                     4.468
# Date:                        Mon, 23 May 2022   Prob (F-statistic):             0.0377
# Time:                                00:29:06   Log-Likelihood:                 4.2892
# No. Observations:                          21   AIC:                             21.42
# Df Residuals:                               6   BIC:                             37.09
# Df Model:                                  14
# Covariance Type:                    nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -1128.6150    607.232     -1.859      0.112   -2614.458     357.228
# Year                            0.5734      0.308      1.862      0.112      -0.180       1.327
# avg_production(Mmcf)         7.278e-08   4.41e-06      0.016      0.987   -1.07e-05    1.09e-05
# avg_consumption(Mmcf)        2.939e-05   3.06e-05      0.961      0.374   -4.54e-05       0.000
# avg_vol(Mmcf)               -1.959e-06   1.44e-06     -1.363      0.222   -5.48e-06    1.56e-06
# avg_total_import(Mmcf)       1.122e-05   1.08e-05      1.034      0.341   -1.53e-05    3.78e-05
# avg_toal_export(Mmcf)       -7.401e-06   1.12e-05     -0.662      0.533   -3.48e-05       2e-05
# avg_import_price($/Mmcf)       -0.3713      0.786     -0.472      0.653      -2.296       1.553
# avg_export_price($/Mmcf)        0.4638      0.926      0.501      0.634      -1.803       2.731
# all_conusmers(Mmcf)            -0.1163      0.167     -0.698      0.511      -0.524       0.291
# commercial_consumers(Mmcf)      0.1163      0.167      0.698      0.511      -0.291       0.524
# electric_consumers(Mmcf)        0.1162      0.167      0.698      0.511      -0.291       0.524
# industrual_consumers(Mcf)       0.1162      0.167      0.698      0.511      -0.291       0.524
# residential_consumers(Mmcf)     0.1162      0.167      0.698      0.511      -0.291       0.524
# vehicle_consumers(Mmcf)         0.1161      0.167      0.697      0.512      -0.292       0.524
# ==============================================================================
# Omnibus:                        5.443   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                3.744
# Skew:                           1.023   Prob(JB):                        0.154
# Kurtosis:                       3.299   Cond. No.                     2.08e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
