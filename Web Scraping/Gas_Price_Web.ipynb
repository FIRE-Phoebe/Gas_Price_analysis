# %%
# Import Splinter, BeautifulSoup, and Pandas
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
import urllib.request

# %%
# Set the executable path and initialize Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\kimbe\.wdm\drivers\chromedriver\win32\101.0.4951.41]

# %% [markdown]
# ## Gas price chart from gas buddy

# %%
# Visit URL
url = 'https://www.gasbuddy.com/charts'
browser.visit(url)

# %%
# Parse the resulting html with soup
html = browser.html
img_soup = soup(html, 'html.parser')
img_soup
# Out:
# <html class="js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" style=""><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="zXhVMaZ-JnjK_v5xNuzXXzO99G76HlIJhiyP31rNWsQ" name="google-site-verification"/>
# <title>Gas Station Price Charts - Local &amp; National Historical Average Trends - GasBuddy.com</title>
# <meta content="Compare gas and crude oil prices over time for the US Average, Canada Average, and your hometown. View charts for the past month to 10 years." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="Gas Station Price Charts - Local &amp; National Historical Average Trends - GasBuddy.com" property="og:title"/>
# <meta content="https://images.gasbuddy.com/images/websites/gasbuddy/apps/cellphone-app.png" property="og:image"/>
# <meta content="Compare gas and crude oil prices over time for the US Average, Canada Average, and your hometown. View charts for the past month to 10 years." property="og:description"/>
# <meta content="Gas Station Price Charts - Local &amp; National Historical Average Trends - Gasbuddy.com" name="twitter:title"/>
# <meta content="https://images.gasbuddy.com/images/websites/gasbuddy/apps/cellphone-app.png" name="twitter:image"/>
# <meta content="Compare gas and crude oil prices over time for the US Average, Canada Average, and your hometown. View charts for the past month to 10 years." name="twitter:description"/>
# <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//static.ads-twitter.com/uwt.js"></script><script async="" src="https://connect.facebook.net/signals/config/366332967829717?v=2.9.61&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://js.datadome.co/tags.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-N3CG6XK"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript"></script><script src="//web.localytics.com/v4/localytics.min.js" type="text/javascript"></script><script src="/cdn-cgi/apps/head/yyzdZdotYv5u2EZFmjDPEBuw9Pw.js"></script><link href="https://images.gasbuddy.com/images/websites/gasbuddy/apple-touch-icon.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="android-app://gbis.gbandroid/gasbuddy/" rel="alternate"/>
# <link href="https://static.gasbuddy.com/web/favicon.ico" id="favicon" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.3.1/css/solid.css" integrity="sha384-VGP9aw4WtGH/uPAOseYxZ+Vz/vaTb1ehm1bwx92Fm8dTrE+3boLfF1SpAtB1z7HW" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.3.1/css/brands.css" integrity="sha384-rf1bqOAj3+pw6NqYrtaE1/4Se2NBwkIfeYbsFdtiR6TQz0acWiwJbv1IM/Nt/ite" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.3.1/css/fontawesome.css" integrity="sha384-1rquJLNOM3ijoueaaeS5m+McXPJCGdr5HcA03/VHXxcp2kX2sUrQDmFc3jR5i/C7" rel="stylesheet"/>
# <link href="/Content/css?v=l4AqRMSmm09fRzHFaQ2DN5eTzvoMZPd7sINXio2n7HA1" rel="stylesheet"/>
# <script src="/Scripts/lib/gasbuddy.main.js?v2"></script>
# <script src="/bundles/modernizr?v=inCVuEFe6J4Q07A0AcRsbJic_UE5MwpRMNGcOtk94TE1"></script>
# <script src="/bundles/jquery?v=cr2m_QBRpjRuuxyjAK9VTfCnKCT-rwItKazh9uX4w_c1"></script>
# <script>
#     +function (l, y, t, i, c, s) {
#         l['LocalyticsGlobal'] = i;
#         l[i] = function () { (l[i].q = l[i].q || []).push(arguments) };
#         l[i].t = +new Date;
#         (s = y.createElement(t)).type = 'text/javascript';
#         s.src = '//web.localytics.com/v4/localytics.min.js';
#         (c = y.getElementsByTagName(t)[0]).parentNode.insertBefore(s, c);
#         ll('init', '4a2e551e52ea25e4f2b0ddc-ec0fc5d0-ed14-11e5-1529-00cef1388a40', {domain: 'gasbuddy.com'} /* Options */);
#     }(window, document, 'script', 'll');
# </script>
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <link href="https://www.gasbuddy.com/charts" rel="canonical"/>
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function () {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') +
#                 '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#
#         var mobileWebAdSlot, topBannerAdSlot;
#
#         googletag.cmd.push(function () {
#             var mobileWebMapping = googletag.sizeMapping()
#                     .addSize([768, 0], [])
#                     .addSize([0, 0], [320, 50])
#                     .build();
#
#             var contentTopMapping = googletag.sizeMapping()
#                 .addSize([768, 0], [[970, 250], [728, 90]])
#                 .addSize([0, 0], [])
#                 .build();
#
#             mobileWebAdSlot = googletag.defineSlot('/1025479/GasBuddy_MobileWeb_320x50_Charts', [320, 50], 'div-gpt-ad-1430835791415-0')
#                 .defineSizeMapping(mobileWebMapping)
#                 .setCollapseEmptyDiv(true)
#                 .addService(googletag.pubads());
#             topBannerAdSlot = googletag.defineSlot('/1025479/GasBuddy_Charts_728x90', [[970, 250], [728, 90]], 'div-gpt-ad-1428529431626-2')
#                 .defineSizeMapping(contentTopMapping)
#                 .setCollapseEmptyDiv(true)
#                 .addService(googletag.pubads());
#
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().disableInitialLoad();
#             googletag.enableServices();
#         });
#     </script>
# <script type="text/javascript">
#     function refreshAdCallback(adBiddingSlot) {
#         apstag.fetchBids({
#             slots: [{
#                 slotID: adBiddingSlot.slotID,
#                 slotName: adBiddingSlot.slotName,
#                 sizes: adBiddingSlot.sizes,
#             }]
#         }, () => {
#             googletag.cmd.push(() => {
#                 apstag.setDisplayBids();
#                 googletag.pubads().refresh([adBiddingSlot.gtmSlot]);
#             });
#         });
#     }
#
#     // This method creates a timer that refreshes a given adBiddingSlot every 30 seconds.
#     //      -If the ad slot ever scrolls out of view or the document is not active, the timer pauses.
#     // This method also uses IntersectionObserver to determine if the ad is out of view.
#     //      -If the window does not have IntersectionObserver loaded, we will not start an interval to refresh them.
#     function createAdRefreshTimer(adBiddingSlot) {
#         var adIsObservable = !!window.IntersectionObserver;
#         var adIsInView = true;
#         var timerInterval = null;
#         var timerProgress = 0;
#         var timerCallback = function() {
#             timerProgress++;
#             if (timerProgress >= 30) {
#                 refreshAdCallback(adBiddingSlot);
#                 timerProgress = 0;
#             }
#         }
#
#         function clearRefreshTimer() {
#             clearInterval(timerInterval);
#             timerInterval = null;
#         }
#
#         function startRefreshTimer() {
#             // ensure we have an active observer, we can actively target the ad slot, the ad is in view, and we don't already have an active timer for this ad
#             if (adIsObservable && !!document.querySelector('#' + adBiddingSlot.slotID) && adIsInView && !timerInterval) {
#                 timerInterval = setInterval(timerCallback, 1000);
#             }
#         }
#
#         function handleVisibilityChange() {
#             if (document.hidden) {
#                 clearRefreshTimer();
#             } else {
#                 startRefreshTimer();
#             }
#         }
#
#         startRefreshTimer();
#
#         // add our event listeners to affect the timer as needed for window and document changes
#         document.addEventListener('visibilitychange', handleVisibilityChange);
#         window.addEventListener('blur', clearRefreshTimer);
#         window.addEventListener('focus', startRefreshTimer);
#
#
#         // ensure the document is ready so the ad slots are observable on the page
#         $(document).ready(function () {
#             if (adIsObservable) {
#                 function observerHandler(changes) {
#                     changes.forEach(change => {
#                         if (change.isIntersecting) {
#                             adIsInView = true;
#                             startRefreshTimer();
#                         } else {
#                             adIsInView = false;
#                             clearRefreshTimer();
#                         }
#                     });
#                 }
#                 var observer = new IntersectionObserver(observerHandler);
#                 var targetAd = document.querySelector('#' + adBiddingSlot.slotID);
#
#                 // There's no point observing an ad that isn't on the page. Therefore, we can kill the timer too.
#                 if (!!targetAd) {
#                     observer.observe(targetAd);
#                 } else {
#                     clearRefreshTimer();
#                 }
#
#             } else {
#                 clearRefreshTimer();
#             }
#         });
#
#         // Ensure our event listeners are cleaned up
#         $(window).unload(function () {
#             document.removeEventListener('visibilitychange', handleVisibilityChange);
#             window.removeEventListener('blur', clearRefreshTimer);
#             window.removeEventListener('focus', startRefreshTimer);
#         });
#     }
# </script>
# <script type="text/javascript">
#     !function (a9, a, p, s, t, A, g) { if (a[a9]) return; function q(c, r) { a[a9]._Q.push([c, r]) } a[a9] = { init: function () { q("i", arguments) }, fetchBids: function () { q("f", arguments) }, setDisplayBids: function () { }, targetingKeys: function () { return [] }, _Q: [] }; A = p.createElement(s); A.async = !0; A.src = t; g = p.getElementsByTagName(s)[0]; g.parentNode.insertBefore(A, g) }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     // initialize apstag and have apstag set bids on the googletag slots when they are returned to the page
#     apstag.init({
#         pubID: '3615',
#         adServer: 'googletag',
#         bidTimeout: 30 * 1000
#     });
#
#     // Create our bidding slots
#     var mobileWebBiddingSlot = {
#         slotID: 'div-gpt-ad-1430835791415-0',
#         slotName: '/1025479/GasBuddy_MobileWeb_320x50_Charts',
#         sizes: [[320, 50]],
#     };
#
#     var topBannerBiddingSlot = {
#         slotID: 'div-gpt-ad-1428529431626-2',
#         slotName: '/1025479/GasBuddy_Charts_728x90',
#         sizes: [[970, 250], [728, 90]],
#     };
#
#     function getNewAds() {
#         // request the bids for the googletag slots
#         apstag.fetchBids({
#             slots: [mobileWebBiddingSlot, topBannerBiddingSlot]
#         }, function (bids) {
#             // set apstag bids, then trigger the first request to DFP
#             googletag.cmd.push(function () {
#                 apstag.setDisplayBids();
#                 googletag.pubads().refresh();
#
#                 // With the ads set, we can add the gtmSlot to our bidding slot objects. GTM Slots are defined in Charts/Index.cshtml
#                 mobileWebBiddingSlot.gtmSlot = mobileWebAdSlot;
#                 topBannerBiddingSlot.gtmSlot = topBannerAdSlot;
#
#                 // Create timers to refresh ads.
#                 createAdRefreshTimer(mobileWebBiddingSlot);
#                 createAdRefreshTimer(topBannerBiddingSlot);
#             })
#         });
#     }
#
#     // Get initial set of ads
#     getNewAds();
# </script>
# <style>
#         .styled-select {
#             cursor: pointer;
#             box-shadow: -1px 1px 4px 0 #CCC;
#             height: 40px;
#             line-height: 40px;
#             overflow: hidden;
#             width: 100%;
#         }
#
#             .styled-select select {
#                 cursor: pointer;
#                 background: transparent;
#                 border: none;
#                 font-size: 14px;
#                 height: 40px;
#                 line-height: 40px;
#                 width: 110%;
#                 padding-left: 15px;
#             }
#
#                 .styled-select select option:first-child {
#                     color: #aaa;
#                 }
#
#
#         .fatCheckbox {
#             cursor: pointer;
#             height: 40px;
#             background: #fff;
#             -moz-box-shadow: 0px 2px 6px rgba(0,0,0,0.2);
#             -webkit-box-shadow: 0px 2px 6px rgba(0,0,0,0.2);
#             box-shadow: 0px 2px 6px rgba(0,0,0,0.2);
#         }
#
#             .fatCheckbox input {
#                 display: none;
#             }
#
#             .fatCheckbox label {
#                 cursor: pointer;
#                 height: 40px;
#                 line-height: 40px;
#                 text-align: center;
#                 width: 100%;
#                 font-weight: normal;
#                 color: #999999;
#                 background-color: #FFFFFF;
#                 border-bottom: 5px solid #FFFFFF;
#             }
#
#         /*.fatCheckbox input:checked + label {
#                 border-bottom-color: #045F68;
#                 color: #000000;
#                 font-weight: bold;
#             }*/
#
#         h2 {
#             margin: 0 0 20px;
#             padding: 0;
#         }
#
#         .no-border {
#             border: none;
#         }
#
#         .copy-width {
#             margin: auto;
#             max-width: 900px;
#             text-align: left;
#         }
#
#         .header-text {
#             color: #039eb1;
#             font-weight: bold;
#         }
#
#         .white-box {
#             padding: 10px;
#         }
#
#         #chartContainer {
#             overflow-y: hidden;
#             overflow-x: hidden;
#         }
#
#         #chartImage {
#             width: 100%;
#             max-width: 670px;
#         }
#
#         #chartMask {
#             display: none;
#         }
#
#             #chartMask img {
#                 position: absolute;
#                 top: 60px;
#                 transform: translateX(-50%);
#             }
#
#
#         .btn.btn-selector.red-label .bs-caret {
#             background: #c9310d;
#         }
#
#         .btn.btn-selector.red-label {
#             background: -webkit-linear-gradient(to left, #c9310d 0, #c9310d 40px, #fff 40px); /* For Safari 5.1 to 6.0 */
#             background: -o-linear-gradient(to left, #c9310d 0, #c9310d 40px, #fff 40px); /* For Opera 11.1 to 12.0 */
#             background: -moz-linear-gradient(to left, #c9310d 0, #c9310d 40px, #fff 40px); /* For Firefox 3.6 to 15 */
#             background: linear-gradient(to left, #c9310d 0, #c9310d 40px, #fff 40px); /* Standard syntax */
#         }
#
#         .btn.btn-selector.green-label .bs-caret {
#             background: #1e7100;
#         }
#
#         .btn.btn-selector.green-label {
#             background: -webkit-linear-gradient(to left, #1e7100 0, #1e7100 40px, #fff 40px); /* For Safari 5.1 to 6.0 */
#             background: -o-linear-gradient(to left, #1e7100 0, #1e7100 40px, #fff 40px); /* For Opera 11.1 to 12.0 */
#             background: -moz-linear-gradient(to left, #1e7100 0, #1e7100 40px, #fff 40px); /* For Firefox 3.6 to 15 */
#             background: linear-gradient(to left, #1e7100 0, #1e7100 40px, #fff 40px); /* Standard syntax */
#         }
#
#         .btn.btn-selector.blue-label .bs-caret {
#             background: #3552dd;
#         }
#
#         .btn.btn-selector.blue-label {
#             background: -webkit-linear-gradient(to left, #3552dd 0, #3552dd 40px, #fff 40px); /* For Safari 5.1 to 6.0 */
#             background: -o-linear-gradient(to left, #3552dd 0, #3552dd 40px, #fff 40px); /* For Opera 11.1 to 12.0 */
#             background: -moz-linear-gradient(to left, #3552dd 0, #3552dd 40px, #fff 40px); /* For Firefox 3.6 to 15 */
#             background: linear-gradient(to left, #3552dd 0, #3552dd 40px, #fff 40px); /* Standard syntax */
#         }
#
#         .findGasPriceContainer {
#             margin: auto;
#             max-width: 670px;
#             text-align: left;
#         }
#
#         .homeTitle {
#             text-align: center;
#         }
#
#         .image-cta {
#             margin: auto;
#             max-width: 900px;
#         }
#     </style>
# <link href="/Content/bootstrap-select.min.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N3CG6XK');</script>
# <!-- End Google Tag Manager -->
# <!-- Start Visual Website Optimizer Asynchronous Code -->
# <script type="text/javascript">
# var _vwo_code=(function(){
# var account_id=344491,
# settings_tolerance=2000,
# library_tolerance=2500,
# use_existing_jquery=false,
# /* DO NOT EDIT BELOW THIS LINE */
# f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());_vwo_settings_timer=_vwo_code.init();
# </script><script src="//dev.visualwebsiteoptimizer.com/j.php?a=344491&amp;u=https%3A%2F%2Fwww.gasbuddy.com%2Fcharts&amp;r=0.4321781179504478" type="text/javascript"></script>
# <!-- End Visual Website Optimizer Asynchronous Code -->
# <meta content="AxujKG9INjsZ8/gUq8+dTruNvk7RjZQ1oFhhgQbcTJKDnZfbzSTE81wvC2Hzaf3TW4avA76LTZEMdiedF1vIbA4AAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2NTI3NzQ0MDAsImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="A88BWHFjcawUfKU3lIejLoryXoyjooBXLgWmGh+hNcqMK44cugvsI5YZbNarYvi3roc1fYbHA1AVbhAtuHZflgEAAAB2eyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjUyNzc0NDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZSwiaXNUaGlyZFBhcnR5Ijp0cnVlfQ==" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2022051901.js?cb=31067739"></script><script src="//secure.cdn.fastclick.net/js/pubcid/latest/pubcid.min.js"></script><iframe srcdoc="/**/" style="display: none;"></iframe><script async="" src="//t.contentsquare.net/uxa/cc04783d52dc4.js" type="text/javascript"></script><link href="https://aba.gumgum.com" rel="preconnect"/><link href="https://g2.gumgum.com" rel="preconnect"/><link href="https://c.gumgum.com" rel="preconnect"/><link href="https://js.gumgum.com" rel="preconnect"/><link href="https://gumgum.com" rel="preconnect"/><meta content="" http-equiv="origin-trial"/><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.gasbuddy.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.gasbuddy.com" type="text/javascript"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/844908342/?random=1653459142806&amp;cv=9&amp;fst=1653459142806&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1032&amp;u_aw=1920&amp;u_cd=24&amp;u_his=2&amp;u_tz=-420&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2oa5n0&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.co ...
# <body><script>!function(a,b,c,d,e,f){a.ddjskey=e;a.ddoptions=f||null;var m=b.createElement(c),n=b.getElementsByTagName(c)[0];m.async=1,m.src=d,n.parentNode.insertBefore(m,n)}(window,document,"script","https://js.datadome.co/tags.js","811351B6FEDEC2D058136271F1855B", {"ajaxListenerPath": true});</script>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-
# N3CG6XK" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="top-ad-container">
# <div class="visible-sm visible-md visible-lg">
# <div class="container">
# <br/>
# <div data-google-query-id="CK2X8Kb_-fcCFSaXpwod_yoCng" id="div-gpt-ad-1428529431626-2" style="text-align:center;">
# <div id="google_ads_iframe_/1025479/GasBuddy_Charts_728x90_0__container__" style="border: 0pt none; display: inline-block; width: 728px; height: 90px;"><iframe aria-label="Advertisement" data-google-container-id="1" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/1025479/GasBuddy_Charts_728x90_0" marginheight="0" marginwidth="0" name="" role="region" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://44a8ab1dda3b00bcb14448d22041c3da.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="border: 0px; vertical-align: bottom;" tabindex="0" title="3rd party ad content" width="728"></iframe></div></div>
# <br/>
# </div>
# </div>
# <div class="visible-xs">
# <!-- /1025479/GasBuddy_Newmobieweb_320x50 -->
# <div id="div-gpt-ad-1430835791415-0" style="height: 50px; width: 320px; margin: 15px auto; display: none;">
# <script type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1430835791415-0'); });
#     </script>
# </div>
# </div>
# </div>
# <nav class="navbar navbar-default" id="topNavbar" role="navigation">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#navbarItems" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="navbar-brand-container">
# <a class="navbar-brand" href="/">
# <img alt="GasBuddy logo" src="https://static.gasbuddy.com/web/gas-buddy-logo-midnight-txt.svg"/>
# </a>
# </div>
# <div class="hidden-md hidden-lg find-gas-container">
# <a class="find-gas-button" href="/home">
#                     Find Gas
#                 </a>
# </div>
# </div>
# <div class="navbar-collapse collapse" id="navbarItems">
# <ul class="nav navbar-nav dropdown">
# <li class="dropdown dropdown-toggle">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="primary-link">Find Gas</span><span class="pull-right fas fa-chevron-down"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="dropdown-item" href="/home">Search</a></li>
# <li class="dropdown-toggle">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">By City<span class="pull-right fas fa-chevron-down"></span></a>
# <ul class="dropdown-menu secondary-menu two-columns">
# <li><a class="dropdown-item" href="/gasprices/georgia/atlanta">Atlanta</a></li>
# <li><a class="dropdown-item" href="/gasprices/massachusetts/boston">Boston</a></li>
# <li><a class="dropdown-item" href="/gasprices/illinois/chicago">Chicago</a></li>
# <li><a class="dropdown-item" href="/gasprices/ohio/cleveland">Cleveland</a></li>
# <li><a class="dropdown-item" href="/gasprices/texas/dallas">Dallas</a></li>
# <li><a class="dropdown-item" href="/gasprices/colorado/denver">Denver</a></li>
# <li><a class="dropdown-item" href="/gasprices/michigan/detroit">Detroit</a></li>
# <li><a class="dropdown-item" href="/gasprices/texas/houston">Houston</a></li>
# <li><a class="dropdown-item" href="/gasprices/california/los-angeles">Los Angeles</a></li>
# <li><a class="dropdown-item" href="/gasprices/florida/miami">Miami</a></li>
# <li><a class="dropdown-item" href="/gasprices/quebec/montreal">Montreal</a></li>
# <li><a class="dropdown-item" href="/gasprices/new-york/new-york-city">New York City</a></li>
# <li><a class="dropdown-item" href="/gasprices/florida/orlando">Orlando</a></li>
# <li><a class="dropdown-item" href="/gasprices/pennsylvania/philadelphia">Philadelphia</a></li>
# <li><a class="dropdown-item" href="/gasprices/arizona/phoenix">Phoenix</a></li>
# <li><a class="dropdown-item" href="/gasprices/california/san-diego">San Diego</a></li>
# <li><a class="dropdown-item" href="/gasprices/california/san-francisco">San Francisco</a></li>
# <li><a class="dropdown-item" href="/gasprices/washington/seattle">Seattle</a></li>
# <li><a class="dropdown-item" href="/gasprices/florida/tampa">Tampa</a></li>
# <li><a class="dropdown-item" href="/gasprices/ontario/toronto">Toronto</a></li>
# <li><a class="dropdown-item" href="/gasprices/washington-dc">Washington DC</a></li>
# <li><a class="see-all-link" href="/gasprices">See All</a></li>
# </ul>
# </li>
# <li class="dropdown-toggle">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">By State &amp; Province<span class="pull-right fas fa-chevron-down"></span></a>
# <ul class="dropdown-menu secondary-menu two-columns">
# <li><a class="dropdown-item" href="/gasprices/alabama">Alabama</a></li>
# <li><a class="dropdown-item" href="/gasprices/arizona">Arizona</a></li>
# <li><a class="dropdown-item" href="/gasprices/california">California</a></li>
# <li><a class="dropdown-item" href="/gasprices/florida">Florida</a></li>
# <li><a class="dropdown-item" href="/gasprices/georgia">Georgia</a></li>
# <li><a class="dropdown-item" href="/gasprices/illinois">Illinois</a></li>
# <li><a class="dropdown-item" href="/gasprices/indiana">Indiana</a></li>
# <li><a class="dropdown-item" href="/gasprices/massachusetts">Massachusetts</a></li>
# <li><a class="dropdown-item" href="/gasprices/michigan">Michigan</a></li>
# <li><a class="dropdown-item" href="/gasprices/missouri">Missouri</a></li>
# <li><a class="dropdown-item" href="/gasprices/new-jersey">New Jersey</a></li>
# <li><a class="dropdown-item" href="/gasprices/new-york">New York</a></li>
# <li><a class="dropdown-item" href="/gasprices/north-carolina">North Carolina</a></li>
# <li><a class="dropdown-item" href="/gasprices/ohio">Ohio</a></li>
# <li><a class="dropdown-item" href="/gasprices/pennsylvania">Pennsylvania</a></li>
# <li><a class="dropdown-item" href="/gasprices/tennessee">Tennessee</a></li>
# <li><a class="dropdown-item" href="/gasprices/texas">Texas</a></li>
# <li><a class="dropdown-item" href="/gasprices/alberta">Alberta</a></li>
# <li><a class="dropdown-item" href="/gasprices/british-columbia">British Columbia</a></li>
# <li><a class="dropdown-item" href="/gasprices/manitoba">Manitoba</a></li>
# <li><a class="dropdown-item" href="/gasprices/ontario">Ontario</a></li>
# <li><a class="dropdown-item" href="/gasprices/quebec">Quebec</a></li>
# <li><a class="dropdown-item" href="/gasprices/saskatchewan">Saskatchewan</a></li>
# <li><a class="see-all-link" href="/gasprices">See All</a></li>
# </ul>
# </li>
# <li class="dropdown-toggle">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">By Brand<span class="pull-right fas fa-chevron-down"></span></a>
# <ul class="dropdown-menu secondary-menu">
# <li><a class="dropdown-item" href="/brands/bp">BP</a></li>
# <li><a class="dropdown-item" href="/brands/citgo">CITGO</a></li>
# <li><a class="dropdown-item" href="/brands/chevron">Chevron</a></li>
# <li><a class="dropdown-item" href="/brands/conoco">Conoco</a></li>
# <li><a class="dropdown-item" href="/brands/exxon">Exxon</a></li>
# <li><a class="dropdown-item" href="/brands/marathon">Marathon</a></li>
# <li><a class="dropdown-item" href="/brands/phillips-66">Phillips 66</a></li>
# <li><a class="dropdown-item" href="/brands/shell">Shell</a></li>
# <li><a class="dropdown-item" href="/brands/valero">Valero</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown dropdown-toggle">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="primary-link">Pay with GasBuddy</span><span class="pull-right fas fa-chevron-down"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="dropdown-item" href="https://enroll.gasbuddy.com">Get The Free Card</a></li>
# <li><a class="dropdown-item" href="/pay">Gas Card Details</a></li>
# <li><a class="dropdown-item" href="/gasback">How GasBack Works</a></li>
# <li><a class="dropdown-item" href="/pay/premium">Premium Membership</a></li>
# </ul>
# </li>
# <li class="dropdown dropdown-toggle">
# <a class="dropdown-toggle selected" data-toggle="dropdown" href="#">
# <span class="primary-link">Gas Tools</span><span class="pull-right fas fa-chevron-down"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="dropdown-item" href="/charts">Gas Price Charts</a></li>
# <li><a class="dropdown-item" href="/gaspricemap">Gas Price Map</a></li>
# <li><a class="dropdown-item" href="https://www.gasbuddy.com/go/fueldemand" target="_blank">Fuel Demand</a></li>
# <li><a class="dropdown-item" href="https://fuelinsights.gasbuddy.com" target="_blank">Fuel Insights</a></li>
# <li><a class="dropdown-item" href="https://tracker.gasbuddy.com" target="_blank">Outage Tracker</a></li>
# <li><a class="dropdown-item" href="/vehicles/recalls/search">Vehicle Recalls</a></li>
# <li><a class="dropdown-item" href="/account/fuel-log-book">Fuel Logbook</a></li>
# </ul>
# </li>
# <li class="standalone-link">
# <a class="" href="/tripcostcalculator">Plan Your Trip</a>
# </li>
# <li class="standalone-link">
# <a href="/go/blog/" target="_blank">Blog</a>
# </li>
# <li class="hidden-md hidden-lg">
# <div class="social-media-badges">
# <a class="social-media-badge" href="https://www.instagram.com/gasbuddy/" target="_blank">
# <span class="fab fa-instagram"></span>
# </a>
# <a class="social-media-badge" href="https://www.facebook.com/gasbuddy" target="_blank">
# <span class="fab fa-facebook"></span>
# </a>
# <a class="social-media-badge" href="https://twitter.com/gasbuddy" target="_blank">
# <span class="fab fa-twitter"></span>
# </a>
# <a class="social-media-badge" href="https://www.linkedin.com/company/gasbuddy" target="_blank">
# <span class="fab fa-linkedin-in"></span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="invisible-nav-div"></div>
# </div>
# </nav>
# <script>
#     $(function () {
#         var stickyHeight = $('nav#topNavbar')[0].offsetTop;
#
#         $(document).ready(function () {
#
#             $('ul.dropdown-menu [data-toggle=dropdown]').on('click', function (event) {
#                 event.preventDefault();
#                 event.stopPropagation();
#                 $(this).parent().siblings().removeClass('open');
#                 $(this).parent().toggleClass('open');
#             });
#
#             $('a.dropdown-item').on('click', function (event) {
#                 logLocalyticsEvent(event);
#             });
#
#             $('a.see-all-link').on('click', function (event) {
#                 logLocalyticsEvent(event);
#             });
#         });
#
#
#         if ($('div.top-ad-container').length) {
#             window.onscroll = function () { makeNavbarSticky() };
#             makeNavbarSticky();
#         } else {
#             $('nav#topNavbar')[0].classList.add('navbar-fixed-top');
#         }
#
#         function makeNavbarSticky() {
#             if (window.pageYOffset > stickyHeight) {
#                 $('nav#topNavbar')[0].classList.add('navbar-fixed-top');
#             }
#
#             if (window.pageYOffset <= stickyHeight) {
#                 $('nav#topNavbar')[0].classList.remove('navbar-fixed-top');
#             }
#         };
#
#         function logLocalyticsEvent(event) {
#             //Follow similar process and naming from new stack
#             var linkName = event.target.innerText;
#             var href = event.currentTarget.attributes.href.value;
#
#             if (linkName === 'Vehicle Recalls') {
#                 ll('tagEvent', 'Open_Recall_Search_Page', { Page: linkName, source: 'MVC_navbar' });
#             } else {
#                 ll('tagEvent', 'MAIN_MENU_ITEM_CLICK', { name: linkName, href: href });
#             }
#         }
#     });
# </script>
# <div class="top-buffer-md body-container">
# <div class="container-fluid bottom-buffer-sm">
# <div class="col-xs-12 bottom-buffer-md">
# <div class="copy-width">
# <h1 class="header-text">Gas Price Charts</h1>
# <p class="white-box bottom-buffer-md">
#                     Do you like to keep up-to-date with historical data for the national average on gas prices compared to where you live or are travelling to?
#                     With 10 years of data and a customizable chart, you can see and compare different areas across the US and Canada on GasBuddy.
#                 </p>
# <a href="/pay" onclick="ll('tagEvent', 'PwGB_Banner_Clicked', { 'Page': 'Charts' });">
# <img alt="Get a Free GasBuddy Card to save up to 25¢/gal at stations nationwide" src="https://static.gasbuddy.com/web/pay/pay-banner-900x90.png" style="width: 100%;"/>
# </a>
# </div>
# </div>
# <div class="col-sm-12 text-center" id="t_chartContainer">
# <img class="t_chartImage img-responsive" id="chartImage" src="https://charts.gasbuddy.com/ch.gaschart?Country=USA&amp;Crude=f&amp;Period=18&amp;Areas=USA+Average%2c%2c&amp;Unit=US+%24%2fG"/>
# <div class="t_chartMask" id="chartMask">
# <img src="https://images.gasbuddy.com/images/websites/gasbuddy/art/ajax.gif"/>
# </div>
# <div class="container bottom-buffer-md">
# <div class="t_chartFormContainer" id="chartForm">
# <div class="row bottom-buffer-md">
# <div class="col-sm-12 text-center">
# <h2>Customize Chart</h2>
# </div>
# <div class="col-sm-4 text-center">
# <div class="btn-group bootstrap-select"><button class="btn dropdown-toggle btn-selector white-caret blue-label" data-id="area1" data-toggle="dropdown" title="USA Average" type="button"><span class="filter-option pull-left">USA Average</span> <span class="bs-caret"><span class="caret"></span></span></button><div class="dropdown-menu open"><div class="bs-searchbox"><input autocomplete="off" class="form-control" type="text"/></div><ul class="dropdown-menu inner" role="menu"><li data-original-index="0"><a class="" data-tokens="clear,none,na,empty,null" style="" tabindex="0"><span class="text">Area 1</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li class="selected" data-original-index="1"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">USA Average</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="2"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Canada Average</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="3"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Abbotsford, BC</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="4"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Akron, OH</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="5"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Alabama, AL</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="6"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Alaska, AK</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="7"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Albany, NY</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="8"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Alberta, AB</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="9"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Albuquerque, NM</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="10"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Allentown, PA</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="11"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Amarillo, TX</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="12"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Anchorage, AK</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="13"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Ann Arbor, MI</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="14"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Appleton, WI</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="15"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Arizona, AZ</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="16"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Arkansas, AR</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="17"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Asheville, NC</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="18"><a class="" data-tokens="null" style="" tabindex="0"><span class="text">Atlanta, GA</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data ...
# <option data-tokens="clear,none,na,empty,null" selected="" value="">Area 1</option>
# <option selected="" value="USA Average">USA Average</option>
# <option value="Canada Average">Canada Average</option>
# <option value="Abbotsford">Abbotsford, BC</option>
# <option value="Akron">Akron, OH</option>
# <option value="Alabama">Alabama, AL</option>
# <option value="Alaska">Alaska, AK</option>
# <option value="Albany">Albany, NY</option>
# <option value="Alberta">Alberta, AB</option>
# <option value="Albuquerque">Albuquerque, NM</option>
# <option value="Allentown">Allentown, PA</option>
# <option value="Amarillo">Amarillo, TX</option>
# <option value="Anchorage">Anchorage, AK</option>
# <option value="AnnArbor">Ann Arbor, MI</option>
# <option value="Appleton">Appleton, WI</option>
# <option value="Arizona">Arizona, AZ</option>
# <option value="Arkansas">Arkansas, AR</option>
# <option value="Asheville">Asheville, NC</option>
# <option value="Atlanta">Atlanta, GA</option>
# <option value="Augusta">Augusta, GA</option>
# <option value="Austin">Austin, TX</option>
# <option value="Bakersfield">Bakersfield, CA</option>
# <option value="Baltimore">Baltimore, MD</option>
# <option value="Barrie">Barrie, ON</option>
# <option value="BatonRouge">Baton Rouge, LA</option>
# <option value="BC">British Columbia, BC</option>
# <option value="Billings">Billings, MT</option>
# <option value="Birmingham">Birmingham, AL</option>
# <option value="Boise">Boise, ID</option>
# <option value="Boston">Boston, MA</option>
# <option value="Bridgeport">Bridgeport, CT</option>
# <option value="Buffalo">Buffalo, NY</option>
# <option value="Burlington">Burlington, VT</option>
# <option value="Calgary">Calgary, AB</option>
# <option value="California">California, CA</option>
# <option value="CapeCoral">Cape Coral, FL</option>
# <option value="Champaign">Champaign, IL</option>
# <option value="Charleston">Charleston, WV</option>
# <option value="Charlotte">Charlotte, NC</option>
# <option value="Chattanooga">Chattanooga, TN</option>
# <option value="Chicago">Chicago, IL</option>
# <option value="Chico">Chico, CA</option>
# <option value="Cincy">Cincinnati, OH</option>
# <option value="Cleveland">Cleveland, OH</option>
# <option value="CollegeStation">College Station, TX</option>
# <option value="Colorado">Colorado, CO</option>
# <option value="ColoradoSprings">Colorado Springs, CO</option>
# <option value="Columbia">Columbia, SC</option>
# <option value="Columbus">Columbus, OH</option>
# <option value="Connecticut">Connecticut, CT</option>
# <option value="CorpusChristi">Corpus Christi, TX</option>
# <option value="Dallas">Dallas, TX</option>
# <option value="Dayton">Dayton, OH</option>
# <option value="Delaware">Delaware, DE</option>
# <option value="Denver">Denver, CO</option>
# <option value="DesMoines">Des Moines, IA</option>
# <option value="Detroit">Detroit, MI</option>
# <option value="Durham">Durham, NC</option>
# <option value="Edmonton">Edmonton, AB</option>
# <option value="ElPaso">El Paso, TX</option>
# <option value="Erie">Erie, PA</option>
# <option value="Eugene">Eugene, OR</option>
# <option value="Evansville">Evansville, IN</option>
# <option value="Fargo">Fargo, ND</option>
# <option value="Fayetteville">Fayetteville, NC</option>
# <option value="Flint">Flint, MI</option>
# <option value="FloridaState">Florida, FL</option>
# <option value="FortCollins">Fort Collins, CO</option>
# <option value="FortWorth">Fort Worth, TX</option>
# <option value="Fresno">Fresno, CA</option>
# <option value="FtWayne">Fort Wayne, IN</option>
# <option value="Gainesville">Gainesville, FL</option>
# <option value="Gary">Gary, IN</option>
# <option value="Georgia">Georgia, GA</option>
# <option value="GrandRapids">Grand Rapids, MI</option>
# <option value="GreenBay">Green Bay, WI</option>
# <option value="Greensboro">Greensboro, NC</option>
# <option value="Greenville">Greenville, SC</option>
# <option value="Hagerstown">Hagerstown, MD</option>
# <option value="Halifax">Halifax, NS</option>
# <option value="Hamilton">Hamilton, ON</option>
# <option value="Harrisburg">Harrisburg, PA</option>
# <option value="Hartford">Hartford, CT</option>
# <option value="Hawaii">Hawaii, HI</option>
# <option value="Honolulu">Honolulu, HI</option>
# <option value="Houston">Houston, TX</option>
# <option value="Huntsville">Huntsville, AL</option>
# <option value="Idaho">Idaho, ID</option>
# <option value="Illinois">Illinois, IL</option>
# <option value="Indiana">Indiana, IN</option>
# <option value="Indy">Indianapolis, IN</option>
# <option value="IowaState">Iowa, IA</option>
# <option value="Jackson">Jackson, MS</option>
# <option value="Jacksonville">Jacksonville, FL</option>
# <option value="Kalamazoo">Kalamazoo, MI</option>
# <option value="Kansas">Kansas, KS</option>
# <option value="KC">Kansas City, MO</option>
# <option value="Kentucky">Kentucky, KY</option>
# <option value="Knoxville">Knoxville, TN</option>
# <option value="KW">Kitchener-Waterloo, ON</option>
# <option value="Lancaster">Lancaster, PA</option>
# <option value="Lansing">Lansing, MI</option>
# <option value="Laredo">Laredo, TX</option>
# <option value="Lexington">Lexington, KY</option>
# <option value="Lincoln">Lincoln, NE</option>
# <option value="LittleRock">Little Rock, AR</option>
# <option value="London">London, ON</option>
# <option value="LongIsland">Long Island, NY</option>
# <option value="LosAngeles">Los Angeles, CA</option>
# <option value="Louisiana">Louisiana, LA</option>
# <option value="Louisville">Louisville, KY</option>
# <option value="Lubbock">Lubbock, TX</option>
# <option value="Macon">Macon, GA</option>
# <option value="Madison">Madison, WI</option>
# <option value="Maine">Maine, ME</option>
# <option value="Manitoba">Manitoba, MB</option>
# <option value="Maryland">Maryland, MD</option>
# <option value="Massachusetts">Massachusetts, MA</option>
# <option value="Medford">Medford, OR</option>
# <option value="Memphis">Memphis, TN</option>
# <option value="Miami">Miami, FL</option>
# <option value="Michigan">Michigan, MI</option>
# <option value="MidlandOdessa">Midland Odessa, TX</option>
# <option value="Milwaukee">Milwaukee, WI</option>
# <option value="Minnesota">Minnesota, MN</option>
# <option value="Mississippi">Mississippi, MS</option>
# <option value="Missouri">Missouri, MO</option>
# <option value="Mobile">Mobile, AL</option>
# <option value="Modesto">Modesto, CA</option>
# <option value="Montana">Montana, MT</option>
# <option value="Montgomery">Montgomery, AL</option>
# <option value="Montreal">Montreal, QC</option>
# <option value="MyrtleBeach">Myrtle Beach, SC</option>
# <option value="Naples">Naples, FL</option>
# <option value="Nashville">Nashville, TN</option>
# <option value="Nebraska">Nebraska, NE</option>
# <option value="Nevada">Nevada, NV</option>
# <option value="NewBrunswick">New Brunswick, NB</option>
# <option value="Newfoundland">Newfoundland, NF</option>
# <option value="NewHampshire">New Hampshire, NH</option>
# <option value="NewHaven">New Haven, CT</option>
# <option value="NewJersey">New Jersey, NJ</option>
# <option value="NewMexico">New Mexico, NM</option>
# <option value="NewOrleans">New Orleans, LA</option>
# <option value="NewYork">New York City, NY</option>
# <option value="NewYorkState">New York, NY</option>
# <option value="NorthCarolina">North Carolina, NC</option>
# <option value="NorthDakota">North Dakota, ND</option>
# <option value="NovaScotia">Nova Scotia, NS</option>
# ...
# </li>
# <li>
# <a class="footer-link" href="/careers">Careers</a>
# </li>
# <li>
# <a class="footer-link" href="/go/blog/" target="_blank">Blog</a>
# </li>
# <li>
# <a class="footer-link" href="/go/empowering-the-consumer/" target="_blank">Stance on Data Privacy</a>
# </li>
# </ul>
# </section>
# <section class="linkGroup">
# <h4 class="footer-header">Work With GasBuddy</h4>
# <ul class="footer-links two-link-height">
# <li>
# <a class="footer-link" href="/go/ads" target="_blank">Advertise</a>
# </li>
# <li>
# <a class="footer-link" href="/go/for_business/business-pages/" target="_blank">Convenience &amp; Fuel Brands</a>
# </li>
# </ul>
# </section>
# <section class="linkGroup">
# <h4 class="footer-header">Media</h4>
# <ul class="footer-links three-link-height">
# <li>
# <a class="footer-link" href="/newsroom">Newsroom</a>
# </li>
# <li>
# <a class="footer-link" href="https://fuelinsights.gasbuddy.com" target="_blank">Fuel Price Data &amp; Analysis</a>
# </li>
# <li>
# <a class="footer-link" href="mailto:press@gasbuddy.com" target="_blank">Press Inquiries</a>
# </li>
# </ul>
# </section>
# <section class="linkGroup">
# <h4 class="footer-header">Support</h4>
# <ul class="footer-links two-link-height">
# <li>
# <a class="footer-link" href="https://help.gasbuddy.com/hc/en-us" target="_blank">Help Center</a>
# </li>
# <li>
# <a class="footer-link" href="https://help.gasbuddy.com/hc/en-us/requests/new" target="_blank">Contact Support</a>
# </li>
# </ul>
# </section>
# </nav>
# <div class="footer-section">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-md-6 text-left">
# <div class="store-links">
# <a href="https://apps.apple.com/us/app/gasbuddy-find-cheap-gas-prices/id406719683?mt=8" target="_blank">
# <img alt="apple store footer button" class="store-badge" src="https://static.gasbuddy.com/web/apple-store-badge.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=gbis.gbandroid" target="_blank">
# <img alt="play store footer button" class="store-badge" src="https://static.gasbuddy.com/web/play-store-badge.png"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-6 text-right">
# <div class="social-media-badges">
# <a class="social-media-badge" href="https://www.instagram.com/gasbuddy/" target="_blank">
# <span class="fab fa-instagram"></span>
# </a>
# <a class="social-media-badge" href="https://www.facebook.com/gasbuddy" target="_blank">
# <span class="fab fa-facebook"></span>
# </a>
# <a class="social-media-badge" href="https://twitter.com/gasbuddy" target="_blank">
# <span class="fab fa-twitter"></span>
# </a>
# <a class="social-media-badge" href="https://www.linkedin.com/company/gasbuddy" target="_blank">
# <span class="fab fa-linkedin-in"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-section">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 info-section policy-section">
# <a class="policy-link" href="https://help.gasbuddy.com/hc/en-us/requests/new?ticket_form_id=360002353354">
#                             Do Not Sell My Personal Information
#                         </a>
# <br/><br/>
# <a class="policy-link" href="/Disclaimer">Terms of Use</a>
# <a class="policy-link" href="/Privacy">Privacy Policy</a>
# </div>
# <div class="col-xs-12 info-section">
# <div class="row">
# <div class="col-xs-12">
#                             © 2022 GasBuddy LLC
#                         </div>
# <br/><br/>
# <div class="col-xs-12">
#                             99 Chauncy Street, <br class="hidden-lg"/>Boston, MA 02111
#                         </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
#     $(function() {
#         $(document).ready(function () {
#             $('h4.footer-header').on('click', function (event) {
#                 if ($(window).width() < 993) {
#                     event.preventDefault();
#                     event.stopPropagation();
#                     $(this).parent().siblings().removeClass('open');
#                     $(this).parent().toggleClass('open');
#                 }
#             });
#         });
#     });
# </script>
# <script src="/bundles/bootstrap?v=Dkl3ou4BsjtXA9FIl7iLvh7mIAOAUJidd7qOVs3obPA1"></script>
# <script src="/bundles/gbcore?v=-T5QLlQH5Ujm1cOYzO8i7SrMpoa4eGp3pJffmz_K1441"></script>
# <script src="/Scripts/bootstrap-select.min.js"></script><script id="" type="text/javascript">(function(){window._uxa=window._uxa||[];try{if("undefined"!==typeof dataLayer){for(var b=!1,a=0;a<dataLayer.length;a++)if("undefined"!==typeof dataLayer[a].userID&&(b=!0),"undefined"!==typeof dataLayer[a].Pay_Program&&window._uxa.push(["setCustomVariable",2,"Pay_Program",dataLayer[a].Pay_Program,3]),"undefined"!==typeof dataLayer[a].event&&"undefined"!==typeof dataLayer[a].Pay_Program&&window._uxa.push(["setCustomVariable",3,"enrollStep",dataLayer[a].event,3]),"undefined"!==typeof dataLayer[a].event&&
# "Pay_Web_Enroll_Complete_Opened"==dataLayer[a].event){var c=new Date;window._uxa.push(["ecommerce:addTransaction",{id:""+c.getTime(),revenue:"1.00"}]);window._uxa.push(["ecommerce:send"])}window._uxa.push(["setCustomVariable",1,"loggedInStatus",b,3])}}catch(d){}"undefined"===typeof CS_CONF?(window._uxa.push(["setPath",window.location.pathname+window.location.hash.replace("#","?__")]),b=document.createElement("script"),b.type="text/javascript",b.async=!0,b.src="//t.contentsquare.net/uxa/cc04783d52dc4.js",
# document.getElementsByTagName("head")[0].appendChild(b)):window._uxa.push(["trackPageview",window.location.pathname+window.location.hash.replace("#","?__")])})();</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","366332967829717");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=366332967829717&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" src="https://www.googletagmanager.com/gtag/js?id=AW-844908342" type="text/javascript"></script>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","o4zxy");twq("track","PageView");</script>
# <script>
#         function makeChart() {
#
#             $('#chartMask').show();
#             var area1 = $('#area1').val();
#             var area2 = $('#area2').val();
#             var area3 = $('#area3').val();
#
#             var months = $('input[name="months"]:checked').val();
#
#             var showCrude = $('#crudeCheckbox').is(':checked') ? "t" : "f";
#
#             var priceUnit = $('input[name="unit"]:checked').val();
#
#             var chartUrl = makeChartUrl({
#                 country: "USA",
#                 showCrude: showCrude,
#                 unit: priceUnit,
#                 months: months,
#                 areas: [area1, area2, area3]
#             });
#
#             //apply the new chart url
#             $('#chartImage').attr('src', chartUrl).load(function () {
#                 $('#chartMask').hide();
#             });
#
#             TrackLLEvent("Historic Gas Charts", "Viewed", getAreas(), true);
#         }
#
#         function urlParam(params, key, value) {
#             if (value) {
#                 params.push(key + "=" + value);
#             }
#         }
#         function makeChartUrl(opts) {
#             var baseUrl = "https://charts.gasbuddy.com/ch.gaschart";
#
#             var params = [];
#             urlParam(params, "Country", opts.country);
#             urlParam(params, "Crude", opts.showCrude);
#             urlParam(params, "Period", opts.months);
#             urlParam(params, "Areas", encodeURIComponent(opts.areas.join()));
#             urlParam(params, "Unit", encodeURIComponent(opts.unit));
#
#             var url = baseUrl;
#             for (var i = 0; i < params.length; i++) {
#                 url += (i == 0 ? "?" : "&") + params[i];
#             }
#             return url;
#         }
#         function getAreas() {
#             return {
#                 "area1": $('#area1').val()
#                     , "area2": $('#area2').val()
#                     , "area3": $('#area3').val()
#             };
#         }
#         $(function () {
#             $(".selectpicker").selectpicker();
#             $('#chartForm input, #chartForm select').change(makeChart);
#
#         });
#     </script>
# <style type="text/css">
#     #enterpriseModal {
#         padding-top: 100px;
#     }
#
#     #enterpriseModalContent {
#         padding: 30px 15px 15px 15px;
#     }
#
#     #enterpriseModalTopIconDiv {
#         margin-top: -75px;
#         padding-bottom: 25px;
#         text-align: center;
#     }
#
#     #enterpriseModalIcon {
#         background-color: white;
#         border: 5px white solid;
#         border-radius: 65px;
#     }
#
#     #enterpriseModalCloseBtn, #enterpriseModalCloseBtn:hover {
#         background-color: #0097a9;
#         background-image: linear-gradient(to bottom, #0097a9 0%, #0097a9 100%);
#         border: 0 none;
#     }
# </style>
# <div class="modal fade" id="enterpriseModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content" id="enterpriseModalContent">
# <div class="modal-header">
# <div id="enterpriseModalTopIconDiv">
# <img alt="Verified Station icon" id="enterpriseModalIcon" src="https://images.gasbuddy.com/images/websites/gasbuddy/enterprise/enterprise-icon-lg.png" title="Enterprise"/>
# </div>
# <h3 class="modal-title text-center">This is a Verified Station</h3>
# </div>
# <div class="modal-body">
# <div class="row top-buffer-md">
# <div class="col-xs-12">
# <p>
#                             The information, amenities, and branding of this station are being monitored by the businesses that keep the doors open and the fuel pumping.
#                             They are actively watching the performance of this station to better connect you with your Perfect Pit Stop.
#                         </p>
# </div>
# </div>
# <div class="row top-buffer-md">
# <div class="col-xs-12">
# <button class="btn btn-primary btn-block btn-lg" data-dismiss="modal" id="enterpriseModalCloseBtn" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     $('#enterpriseModal').on('show.bs.modal', function (e) {
#         if ($('#stationMap').length > 0) {
#             $('#stationMap').css("display", "none");
#         }
#
#         if ($('#TR-stations-panel').length > 0) {
#             $('#TR-stations-panel').css("display", "none");
#         }
#
#         try {
#             ll('tagEvent', 'Viewed Enterprise Popup', { 'Page_URL': window.location.pathname });
#         } catch (err) {
#             console.error(err);
#         }
#     });
#
#     $('#enterpriseModal').on('hidden.bs.modal', function (e) {
#         if ($('#stationMap').length > 0) {
#             $('#stationMap').css("display", "block");
#         }
#
#         if ($('#TR-stations-panel').length > 0) {
#             $('#TR-stations-panel').css("display", "block");
#         }
#     });
# </script>
# <script type="text/javascript">ll('tagScreen', 'Gas Station Price Charts - Local &amp; National Historical Average Trends');</script>
# <script type="text/javascript">ggv2id = 'bfce2827';</script>
# <script src="https://g2.gumgum.com/javascripts/ggv2.js" type="text/javascript"></script>
# <div id="g1653459142483" style="color: initial; font: initial; font-feature-settings: initial; font-kerning: initial; font-optical-sizing: initial; font-palette: initial; font-synthesis: initial; font-variation-settings: initial; forced-color-adjust: initial; text-orientation: initial; text-rendering: initial; -webkit-font-smoothing: initial; -webkit-locale: initial; -webkit-text-orientation: initial; -webkit-writing-mode: initial; writing-mode: initial; zoom: initial; accent-color: initial; place-content: initial; place-items: initial; place-self: initial; alignment-baseline: initial; animation: initial; app-region: initial; appearance: initial; aspect-ratio: initial; backdrop-filter: initial; backface-visibility: initial; background: initial; background-blend-mode: initial; baseline-shift: initial; block-size: initial; border-block: initial; border: initial; border-radius: initial; border-collapse: initial; border-end-end-radius: initial; border-end-start-radius: initial; border-inline: initial; border-start-end-radius: initial; border-start-start-radius: initial; inset: initial; box-shadow: initial; box-sizing: initial; break-after: initial; break-before: initial; break-inside: initial; buffered-rendering: initial; caption-side: initial; caret-color: initial; clear: initial; clip: initial; clip-path: initial; clip-rule: initial; color-interpolation: initial; color-interpolation-filters: initial; color-rendering: initial; color-scheme: initial; columns: initial; column-fill: initial; gap: initial; column-rule: initial; column-span: initial; contain: initial; contain-intrinsic-block-size: initial; contain-intrinsic-size: initial; contain-intrinsic-inline-size: initial; content: initial; content-visibility: initial; counter-increment: initial; counter-reset: initial; counter-set: initial; cursor: initial; cx: initial; cy: initial; d: initial; display: block; dominant-baseline: initial; empty-cells: initial; fill: initial; fill-opacity: initial; fill-rule: initial; filter: initial; flex: initial; flex-flow: initial; float: initial; flood-color: initial; flood-opacity: initial; grid: initial; grid-area: initial; height: 0px; hyphens: initial; image-orientation: initial; image-rendering: initial; inline-size: initial; inset-block: initial; inset-inline: initial; isolation: initial; letter-spacing: initial; lighting-color: initial; line-break: initial; list-style: initial; margin-block: initial; margin: initial; margin-inline: initial; marker: initial; mask: initial; mask-type: initial; max-block-size: initial; max-height: initial; max-inline-size: initial; max-width: initial; min-block-size: initial; min-height: initial; min-inline-size: initial; min-width: initial; mix-blend-mode: initial; object-fit: initial; object-position: initial; offset: initial; opacity: initial; order: initial; origin-trial-test-property: initial; orphans: initial; outline: initial; outline-offset: initial; overflow-anchor: initial; overflow-clip-margin: initial; overflow-wrap: initial; overflow: initial; overscroll-behavior-block: initial; overscroll-behavior-inline: initial; overscroll-behavior: initial; padding-block: initial; padding: initial; padding-inline: initial; page: initial; page-orientation: initial; paint-order: initial; perspective: initial; perspective-origin: initial; pointer-events: initial; position: initial; quotes: initial; r: initial; resize: initial; ruby-position: initial; rx: initial; ry: initial; scroll-behavior: initial; scroll-margin-block: initial; scroll-margin: initial; scroll-margin-inline: initial; scroll-padding-block: initial; scroll-padding: initial; scroll-padding-inline: initial; scroll-snap-align: initial; scroll-snap-stop: initial; scroll-snap-type: initial; scrollbar-gutter: initial; shape-image-threshold: initial; shape-margin: initial; shape-outside: initial; shape-rendering: initial; size: initial; speak: initial; stop-color: initial; stop-opacity: initial; stroke: initial; stroke-dasharray: initial; stroke-das ...
# <script id="" type="text/javascript">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","AW-844908342");</script><iframe src="https://44a8ab1dda3b00bcb14448d22041c3da.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe><iframe src="https://s.amazon-adsystem.com/iu3?cm3ppd=1&amp;d=dtb-pub&amp;csif=t&amp;dl=n-smaato_pm-db5_rbd_n-emx_n-vmg_cnv_an-db5_3lift" style="display: none;"></iframe></body></html>

# %%
# find the relative image url
img_url_rel = img_soup.find('img', class_='t_chartImage img-responsive')
img_url_rel
# Out:
# <img class="t_chartImage img-responsive" id="chartImage" src="https://charts.gasbuddy.com/ch.gaschart?Country=USA&amp;Crude=f&amp;Period=18&amp;Areas=USA+Average%2c%2c&amp;Unit=US+%24%2fG"/>

# %%
# Use the base url to create an absolute url
img_url = f'https://www.gasbuddy.com/charts/{img_url_rel}'
img_url
# Out:
# 'https://www.gasbuddy.com/charts/<img class="t_chartImage img-responsive" id="chartImage" src="https://charts.gasbuddy.com/ch.gaschart?Country=USA&amp;Crude=f&amp;Period=18&amp;Areas=USA+Average%2c%2c&amp;Unit=US+%24%2fG"/>'

# %% [markdown]
# ## Scrape News Titles

# %%
# 1. Use browser to visit the URL 
url = 'https://gasprices.aaa.com/news/'

browser.visit(url)

# %%
from bs4 import BeautifulSoup as Soup
import requests
from splinter import Browser
import pandas as pd
from selenium import webdriver

# %%
# Parse the html with Beautiful Soup
html = browser.html
html_soup = soup(html, 'html.parser')

# 2. Create a list to hold the images and titles
news_urls = []

# 3. Write code to retrieve the image urls and titles for each hemisphere.

# select finds multiple instances and returns a LIST, find finds the first, 
# so they don't do the same thing. select_one would be the equivalent to find.
# NEED TO PUT IMG URL TO RESULT_LIST
result_list =[]
results = html_soup.select('article')

# %%
for result in results:
    news_link = result.find('a')['href']
    result_list.append(news_link)

# %%
# NEED TO LOOP THRU EACH RESULT_LIST FOR HEMISPHERE FULL IMAGES 
for news_url in result_list:
    browser.visit(f'{url}{news_url}')
    news_html = browser.html
    news_soup = soup(news_html, 'html.parser')
    
    news_urls = news_soup.select('a')
    for news in news_urls:
        news_url = news.text
    print(news_link)
#     full_resolution_jpgs = news_soup.select('div.singl-post')
#     for image in full_resolution_jpgs:
#         jpg_url = image.find('a')['href']
        
#     news_image_urls.append({"title":news_title,"image_url": f'{url}{jpg_url}'})
# Out:
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/
# https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/

# %%
# 4. Print the list that holds the dictionary of each image url and title.
news_link
# Out:
# 'https://gasprices.aaa.com/volatile-crude-oil-prices-continue-to-drive-pump-prices/'

# %%
# 5. Quit the browser
browser.quit()
