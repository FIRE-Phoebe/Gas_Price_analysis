# %% [markdown]
# # California_Regular_All_Formulations_Retail_Gasoline_Prices

# %%
import pandas as pd

# %%
cali_all_form_retail_gas_prices_df = pd.read_csv('Resources/California_Regular_All_Formulations_Retail_Gasoline_Prices.csv',skiprows=4)
cali_all_form_retail_gas_prices_df
# Out:
#         Month  \
# 0    Apr 2022
# 1    Mar 2022
# 2    Feb 2022
# 3    Jan 2022
# 4    Dec 2021
# ..        ...
# 258  Oct 2000
# 259  Sep 2000
# 260  Aug 2000
# 261  Jul 2000
# 262  Jun 2000
#
#      California Regular All Formulations Retail Gasoline Prices Dollars per Gallon
# 0                                                5.598
# 1                                                5.562
# 2                                                4.568
# 3                                                4.495
# 4                                                4.508
# ..                                                 ...
# 258                                              1.812
# 259                                              1.826
# 260                                              1.676
# 261                                              1.710
# 262                                              1.622
#
# [263 rows x 2 columns]

# %%
cali_all_form_retail_gas_prices_df["Date"] = pd.to_datetime(cali_all_form_retail_gas_prices_df["Month"])
cali_all_form_retail_gas_prices_df.head()
# Out:
#       Month  \
# 0  Apr 2022
# 1  Mar 2022
# 2  Feb 2022
# 3  Jan 2022
# 4  Dec 2021
#
#    California Regular All Formulations Retail Gasoline Prices Dollars per Gallon  \
# 0                                              5.598
# 1                                              5.562
# 2                                              4.568
# 3                                              4.495
# 4                                              4.508
#
#         Date
# 0 2022-04-01
# 1 2022-03-01
# 2 2022-02-01
# 3 2022-01-01
# 4 2021-12-01

# %%
cali_all_form_retail_gas_prices_df = pd.DataFrame(data=cali_all_form_retail_gas_prices_df, columns=["Date",
            "California Regular All Formulations Retail Gasoline Prices Dollars per Gallon"])
cali_all_form_retail_gas_prices_df
# Out:
#           Date  \
# 0   2022-04-01
# 1   2022-03-01
# 2   2022-02-01
# 3   2022-01-01
# 4   2021-12-01
# ..         ...
# 258 2000-10-01
# 259 2000-09-01
# 260 2000-08-01
# 261 2000-07-01
# 262 2000-06-01
#
#      California Regular All Formulations Retail Gasoline Prices Dollars per Gallon
# 0                                                5.598
# 1                                                5.562
# 2                                                4.568
# 3                                                4.495
# 4                                                4.508
# ..                                                 ...
# 258                                              1.812
# 259                                              1.826
# 260                                              1.676
# 261                                              1.710
# 262                                              1.622
#
# [263 rows x 2 columns]

# %%
cali_all_form_retail_gas_prices_df= cali_all_form_retail_gas_prices_df.rename(columns={"Date":"Year-Month",
        "California Regular All Formulations Retail Gasoline Prices Dollars per Gallon":"Price per Gallon"})
cali_all_form_retail_gas_prices_df
# Out:
#     Year-Month  Price per Gallon
# 0   2022-04-01             5.598
# 1   2022-03-01             5.562
# 2   2022-02-01             4.568
# 3   2022-01-01             4.495
# 4   2021-12-01             4.508
# ..         ...               ...
# 258 2000-10-01             1.812
# 259 2000-09-01             1.826
# 260 2000-08-01             1.676
# 261 2000-07-01             1.710
# 262 2000-06-01             1.622
#
# [263 rows x 2 columns]

# %%
cali_all_form_retail_gas_prices_df['Year'] = cali_all_form_retail_gas_prices_df['Year-Month'].dt.year
cali_all_form_retail_gas_prices_df['Month'] = cali_all_form_retail_gas_prices_df['Year-Month'].dt.month
cali_all_form_retail_gas_prices_df
# Out:
#     Year-Month  Price per Gallon  Year  Month
# 0   2022-04-01             5.598  2022      4
# 1   2022-03-01             5.562  2022      3
# 2   2022-02-01             4.568  2022      2
# 3   2022-01-01             4.495  2022      1
# 4   2021-12-01             4.508  2021     12
# ..         ...               ...   ...    ...
# 258 2000-10-01             1.812  2000     10
# 259 2000-09-01             1.826  2000      9
# 260 2000-08-01             1.676  2000      8
# 261 2000-07-01             1.710  2000      7
# 262 2000-06-01             1.622  2000      6
#
# [263 rows x 4 columns]

# %%
cali_all_form_retail_gas_prices_df.columns
# Out:
# Index(['Year-Month', 'Price per Gallon', 'Year', 'Month'], dtype='object')

# %%
cali_all_form_retail_gas_prices_df= cali_all_form_retail_gas_prices_df.drop(["Year-Month"],axis=1)
cali_all_form_retail_gas_prices_df
# Out:
#      Price per Gallon  Year  Month
# 0               5.598  2022      4
# 1               5.562  2022      3
# 2               4.568  2022      2
# 3               4.495  2022      1
# 4               4.508  2021     12
# ..                ...   ...    ...
# 258             1.812  2000     10
# 259             1.826  2000      9
# 260             1.676  2000      8
# 261             1.710  2000      7
# 262             1.622  2000      6
#
# [263 rows x 3 columns]

# %%
cali_all_form_retail_gas_prices_df= pd.DataFrame(data =cali_all_form_retail_gas_prices_df,
                                        columns={'Year':'Year',
                                                 'Month':'Month',
                                                'Price per Gallon': 'Price per Gallon'})
cali_all_form_retail_gas_prices_df
# Out:
#      Year  Month  Price per Gallon
# 0    2022      4             5.598
# 1    2022      3             5.562
# 2    2022      2             4.568
# 3    2022      1             4.495
# 4    2021     12             4.508
# ..    ...    ...               ...
# 258  2000     10             1.812
# 259  2000      9             1.826
# 260  2000      8             1.676
# 261  2000      7             1.710
# 262  2000      6             1.622
#
# [263 rows x 3 columns]

# %%
cali_all_form_retail_gas_prices_df = cali_all_form_retail_gas_prices_df[(cali_all_form_retail_gas_prices_df.Year >= int(2001))]
cali_all_form_retail_gas_prices_df
# Out:
#      Year  Month  Price per Gallon
# 0    2022      4             5.598
# 1    2022      3             5.562
# 2    2022      2             4.568
# 3    2022      1             4.495
# 4    2021     12             4.508
# ..    ...    ...               ...
# 251  2001      5             1.948
# 252  2001      4             1.793
# 253  2001      3             1.693
# 254  2001      2             1.637
# 255  2001      1             1.601
#
# [256 rows x 3 columns]

# %%
cali_all_form_retail_gas_prices_df = cali_all_form_retail_gas_prices_df[2:]
cali_all_form_retail_gas_prices_df
# cali_all_form_retail_gas_prices_df = cali_all_form_retail_gas_prices_df.reset_index()
# cali_all_form_retail_gas_prices_df
# Out:
#      Year  Month  Price per Gallon
# 2    2022      2             4.568
# 3    2022      1             4.495
# 4    2021     12             4.508
# 5    2021     11             4.510
# 6    2021     10             4.310
# ..    ...    ...               ...
# 251  2001      5             1.948
# 252  2001      4             1.793
# 253  2001      3             1.693
# 254  2001      2             1.637
# 255  2001      1             1.601
#
# [254 rows x 3 columns]

# %%
cali_all_form_retail_gas_prices_df = cali_all_form_retail_gas_prices_df.reset_index()
cali_all_form_retail_gas_prices_df
# Out:
#      level_0  index  Year  Month  Price per Gallon
# 0          0      2  2022      2             4.568
# 1          1      3  2022      1             4.495
# 2          2      4  2021     12             4.508
# 3          3      5  2021     11             4.510
# 4          4      6  2021     10             4.310
# ..       ...    ...   ...    ...               ...
# 249      249    251  2001      5             1.948
# 250      250    252  2001      4             1.793
# 251      251    253  2001      3             1.693
# 252      252    254  2001      2             1.637
# 253      253    255  2001      1             1.601
#
# [254 rows x 5 columns]

# %%
cali_all_form_retail_gas_prices_df = cali_all_form_retail_gas_prices_df.drop(columns=["level_0", "index"])
cali_all_form_retail_gas_prices_df
# Out:
#      Year  Month  Price per Gallon
# 0    2022      2             4.568
# 1    2022      1             4.495
# 2    2021     12             4.508
# 3    2021     11             4.510
# 4    2021     10             4.310
# ..    ...    ...               ...
# 249  2001      5             1.948
# 250  2001      4             1.793
# 251  2001      3             1.693
# 252  2001      2             1.637
# 253  2001      1             1.601
#
# [254 rows x 3 columns]

# %%
import os
cali_all_form_retail_gas_prices_df.to_csv('Resources/cali_all_form_retail_gas_prices.csv', index=False)

# %% [markdown]
# # Work on Price of U.S. Natural Gas Exports

# %%
import pandas as pd

# %%
exports_price_df = pd.read_csv('Resources/Price_of_U.S._Natural_Gas_Exports.csv',skiprows=4)
exports_price_df.head(10)
# Out:
#       Month  \
# 0  Feb 2022
# 1  Jan 2022
# 2  Dec 2021
# 3  Nov 2021
# 4  Oct 2021
# 5  Sep 2021
# 6  Aug 2021
# 7  Jul 2021
# 8  Jun 2021
# 9  May 2021
#
#    Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet
# 0                                               8.22
# 1                                               7.04
# 2                                               7.40
# 3                                               8.10
# 4                                               7.97
# 5                                               6.70
# 6                                               6.06
# 7                                               5.64
# 8                                               4.92
# 9                                               4.89

# %% [markdown]
# # Work on Price of U.S. Natural Gas Imports

# %%
imports_price_df = pd.read_csv('Resources/Price_of_U.S._Natural_Gas_Imports.csv',skiprows=4)
imports_price_df.head(10)
# Out:
#       Month  \
# 0  Feb 2022
# 1  Jan 2022
# 2  Dec 2021
# 3  Nov 2021
# 4  Oct 2021
# 5  Sep 2021
# 6  Aug 2021
# 7  Jul 2021
# 8  Jun 2021
# 9  May 2021
#
#    Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet
# 0                                               5.62
# 1                                               6.87
# 2                                               4.74
# 3                                               5.18
# 4                                               4.79
# 5                                               4.07
# 6                                               3.52
# 7                                               3.41
# 8                                               2.83
# 9                                               2.70

# %% [markdown]
# # Merge Exports_df and imports_df

# %%
us_price_export_import = imports_price_df.merge(exports_price_df, how='left', on = 'Month')
us_price_export_import
# Out:
#         Month  \
# 0    Feb 2022
# 1    Jan 2022
# 2    Dec 2021
# 3    Nov 2021
# 4    Oct 2021
# ..        ...
# 393  May 1989
# 394  Apr 1989
# 395  Mar 1989
# 396  Feb 1989
# 397  Jan 1989
#
#      Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet  \
# 0                                                 5.62
# 1                                                 6.87
# 2                                                 4.74
# 3                                                 5.18
# 4                                                 4.79
# ..                                                 ...
# 393                                               1.76
# 394                                               1.73
# 395                                               1.81
# 396                                               1.88
# 397                                               1.72
#
#      Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet
# 0                                                 8.22
# 1                                                 7.04
# 2                                                 7.40
# 3                                                 8.10
# 4                                                 7.97
# ..                                                 ...
# 393                                               2.44
# 394                                               2.33
# 395                                               2.40
# 396                                               2.40
# 397                                               2.69
#
# [398 rows x 3 columns]

# %%
us_price_export_import["Date"] = pd.to_datetime(us_price_export_import["Month"])
us_price_export_import.head()
# Out:
#       Month  \
# 0  Feb 2022
# 1  Jan 2022
# 2  Dec 2021
# 3  Nov 2021
# 4  Oct 2021
#
#    Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet  \
# 0                                               5.62
# 1                                               6.87
# 2                                               4.74
# 3                                               5.18
# 4                                               4.79
#
#    Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet  \
# 0                                               8.22
# 1                                               7.04
# 2                                               7.40
# 3                                               8.10
# 4                                               7.97
#
#         Date
# 0 2022-02-01
# 1 2022-01-01
# 2 2021-12-01
# 3 2021-11-01
# 4 2021-10-01

# %%
us_price_export_import= us_price_export_import.drop(["Month"],axis=1)
us_price_export_import
# Out:
#      Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet  \
# 0                                                 5.62
# 1                                                 6.87
# 2                                                 4.74
# 3                                                 5.18
# 4                                                 4.79
# ..                                                 ...
# 393                                               1.76
# 394                                               1.73
# 395                                               1.81
# 396                                               1.88
# 397                                               1.72
#
#      Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet  \
# 0                                                 8.22
# 1                                                 7.04
# 2                                                 7.40
# 3                                                 8.10
# 4                                                 7.97
# ..                                                 ...
# 393                                               2.44
# 394                                               2.33
# 395                                               2.40
# 396                                               2.40
# 397                                               2.69
#
#           Date
# 0   2022-02-01
# 1   2022-01-01
# 2   2021-12-01
# 3   2021-11-01
# 4   2021-10-01
# ..         ...
# 393 1989-05-01
# 394 1989-04-01
# 395 1989-03-01
# 396 1989-02-01
# 397 1989-01-01
#
# [398 rows x 3 columns]

# %%
us_price_export_import.columns
# Out:
# Index(['Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet',
#        'Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet',
#        'Date'],
#       dtype='object')

# %%
us_price_export_import = pd.DataFrame(data=us_price_export_import, columns={'Date',
            "Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet",
            "Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet"})
us_price_export_import
# Out:
#           Date  \
# 0   2022-02-01
# 1   2022-01-01
# 2   2021-12-01
# 3   2021-11-01
# 4   2021-10-01
# ..         ...
# 393 1989-05-01
# 394 1989-04-01
# 395 1989-03-01
# 396 1989-02-01
# 397 1989-01-01
#
#      Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet  \
# 0                                                 5.62
# 1                                                 6.87
# 2                                                 4.74
# 3                                                 5.18
# 4                                                 4.79
# ..                                                 ...
# 393                                               1.76
# 394                                               1.73
# 395                                               1.81
# 396                                               1.88
# 397                                               1.72
#
#      Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet
# 0                                                 8.22
# 1                                                 7.04
# 2                                                 7.40
# 3                                                 8.10
# 4                                                 7.97
# ..                                                 ...
# 393                                               2.44
# 394                                               2.33
# 395                                               2.40
# 396                                               2.40
# 397                                               2.69
#
# [398 rows x 3 columns]

# %%
us_price_export_import=us_price_export_import.rename(columns={"Date":"Year-Month",
        "Price of U.S. Natural Gas Imports  Dollars per Thousand Cubic Feet":"Imports_Price_per_Gallon",
        "Price of U.S. Natural Gas Exports  Dollars per Thousand Cubic Feet":"Exports_Price_per_Gallon"})
us_price_export_import
# Out:
#     Year-Month  Imports_Price_per_Gallon  Exports_Price_per_Gallon
# 0   2022-02-01                      5.62                      8.22
# 1   2022-01-01                      6.87                      7.04
# 2   2021-12-01                      4.74                      7.40
# 3   2021-11-01                      5.18                      8.10
# 4   2021-10-01                      4.79                      7.97
# ..         ...                       ...                       ...
# 393 1989-05-01                      1.76                      2.44
# 394 1989-04-01                      1.73                      2.33
# 395 1989-03-01                      1.81                      2.40
# 396 1989-02-01                      1.88                      2.40
# 397 1989-01-01                      1.72                      2.69
#
# [398 rows x 3 columns]

# %%
us_price_export_import['Year'] = us_price_export_import['Year-Month'].dt.year
us_price_export_import['Month'] = us_price_export_import['Year-Month'].dt.month
us_price_export_import
# Out:
#     Year-Month  Imports_Price_per_Gallon  Exports_Price_per_Gallon  Year  \
# 0   2022-02-01                      5.62                      8.22  2022
# 1   2022-01-01                      6.87                      7.04  2022
# 2   2021-12-01                      4.74                      7.40  2021
# 3   2021-11-01                      5.18                      8.10  2021
# 4   2021-10-01                      4.79                      7.97  2021
# ..         ...                       ...                       ...   ...
# 393 1989-05-01                      1.76                      2.44  1989
# 394 1989-04-01                      1.73                      2.33  1989
# 395 1989-03-01                      1.81                      2.40  1989
# 396 1989-02-01                      1.88                      2.40  1989
# 397 1989-01-01                      1.72                      2.69  1989
#
#      Month
# 0        2
# 1        1
# 2       12
# 3       11
# 4       10
# ..     ...
# 393      5
# 394      4
# 395      3
# 396      2
# 397      1
#
# [398 rows x 5 columns]

# %%
us_price_export_import.columns
# Out:
# Index(['Year-Month', 'Imports_Price_per_Gallon', 'Exports_Price_per_Gallon',
#        'Year', 'Month'],
#       dtype='object')

# %%
us_price_export_import= us_price_export_import.drop(["Year-Month"],axis=1)
us_price_export_import
# Out:
#      Imports_Price_per_Gallon  Exports_Price_per_Gallon  Year  Month
# 0                        5.62                      8.22  2022      2
# 1                        6.87                      7.04  2022      1
# 2                        4.74                      7.40  2021     12
# 3                        5.18                      8.10  2021     11
# 4                        4.79                      7.97  2021     10
# ..                        ...                       ...   ...    ...
# 393                      1.76                      2.44  1989      5
# 394                      1.73                      2.33  1989      4
# 395                      1.81                      2.40  1989      3
# 396                      1.88                      2.40  1989      2
# 397                      1.72                      2.69  1989      1
#
# [398 rows x 4 columns]

# %%
us_price_export_import= pd.DataFrame(data =us_price_export_import,
                                        columns={'Year':'Year',
                                                 'Month':'Month',
                                                'Exports_Price_per_Gallon': 'Exports_Price_per_Gallon',
                                                'Imports_Price_per_Gallon': 'Imports_Price_per_Gallon'})
us_price_export_import
# Out:
#      Year  Month  Exports_Price_per_Gallon  Imports_Price_per_Gallon
# 0    2022      2                      8.22                      5.62
# 1    2022      1                      7.04                      6.87
# 2    2021     12                      7.40                      4.74
# 3    2021     11                      8.10                      5.18
# 4    2021     10                      7.97                      4.79
# ..    ...    ...                       ...                       ...
# 393  1989      5                      2.44                      1.76
# 394  1989      4                      2.33                      1.73
# 395  1989      3                      2.40                      1.81
# 396  1989      2                      2.40                      1.88
# 397  1989      1                      2.69                      1.72
#
# [398 rows x 4 columns]

# %% [markdown]
# # US Natural Gas Underground Storage Volume

# %%
storage_vol_df = pd.read_csv('Resources/U.S._Natural_Gas_Underground_Storage_Volume.csv',skiprows=4)
storage_vol_df
# Out:
#         Month  U.S. Natural Gas Underground Storage Volume  Million Cubic Feet
# 0    Feb 2022                                          5997164.0
# 1    Jan 2022                                          6653327.0
# 2    Dec 2021                                          7647859.0
# 3    Nov 2021                                          7971480.0
# 4    Oct 2021                                          8103211.0
# ..        ...                                                ...
# 574  Apr 1974                                                NaN
# 575  Mar 1974                                                NaN
# 576  Feb 1974                                                NaN
# 577  Jan 1974                                                NaN
# 578  Dec 1973                                          4898000.0
#
# [579 rows x 2 columns]

# %%
storage_vol_df["Date"] = pd.to_datetime(storage_vol_df["Month"])
storage_vol_df.head()
# Out:
#       Month  U.S. Natural Gas Underground Storage Volume  Million Cubic Feet  \
# 0  Feb 2022                                          5997164.0
# 1  Jan 2022                                          6653327.0
# 2  Dec 2021                                          7647859.0
# 3  Nov 2021                                          7971480.0
# 4  Oct 2021                                          8103211.0
#
#         Date
# 0 2022-02-01
# 1 2022-01-01
# 2 2021-12-01
# 3 2021-11-01
# 4 2021-10-01

# %%
storage_vol_df.columns
# Out:
# Index(['Month',
#        'U.S. Natural Gas Underground Storage Volume  Million Cubic Feet',
#        'Date'],
#       dtype='object')

# %%
storage_vol_df = pd.DataFrame(data=storage_vol_df, columns=["Date",
            "U.S. Natural Gas Underground Storage Volume  Million Cubic Feet"])
storage_vol_df
# Out:
#           Date  \
# 0   2022-02-01
# 1   2022-01-01
# 2   2021-12-01
# 3   2021-11-01
# 4   2021-10-01
# ..         ...
# 574 1974-04-01
# 575 1974-03-01
# 576 1974-02-01
# 577 1974-01-01
# 578 1973-12-01
#
#      U.S. Natural Gas Underground Storage Volume  Million Cubic Feet
# 0                                            5997164.0
# 1                                            6653327.0
# 2                                            7647859.0
# 3                                            7971480.0
# 4                                            8103211.0
# ..                                                 ...
# 574                                                NaN
# 575                                                NaN
# 576                                                NaN
# 577                                                NaN
# 578                                          4898000.0
#
# [579 rows x 2 columns]

# %%
storage_vol_df=storage_vol_df.rename(columns={"Date":"Year-Month",
        "U.S. Natural Gas Underground Storage Volume  Million Cubic Feet":"Volume_Mmcf"})
storage_vol_df
# Out:
#     Year-Month  Volume_Mmcf
# 0   2022-02-01    5997164.0
# 1   2022-01-01    6653327.0
# 2   2021-12-01    7647859.0
# 3   2021-11-01    7971480.0
# 4   2021-10-01    8103211.0
# ..         ...          ...
# 574 1974-04-01          NaN
# 575 1974-03-01          NaN
# 576 1974-02-01          NaN
# 577 1974-01-01          NaN
# 578 1973-12-01    4898000.0
#
# [579 rows x 2 columns]

# %%
storage_vol_df['Year'] = storage_vol_df['Year-Month'].dt.year
storage_vol_df['Month'] = storage_vol_df['Year-Month'].dt.month
storage_vol_df
# Out:
#     Year-Month  Volume_Mmcf  Year  Month
# 0   2022-02-01    5997164.0  2022      2
# 1   2022-01-01    6653327.0  2022      1
# 2   2021-12-01    7647859.0  2021     12
# 3   2021-11-01    7971480.0  2021     11
# 4   2021-10-01    8103211.0  2021     10
# ..         ...          ...   ...    ...
# 574 1974-04-01          NaN  1974      4
# 575 1974-03-01          NaN  1974      3
# 576 1974-02-01          NaN  1974      2
# 577 1974-01-01          NaN  1974      1
# 578 1973-12-01    4898000.0  1973     12
#
# [579 rows x 4 columns]

# %%
storage_vol_df= storage_vol_df.drop(["Year-Month"],axis=1)
storage_vol_df
# Out:
#      Volume_Mmcf  Year  Month
# 0      5997164.0  2022      2
# 1      6653327.0  2022      1
# 2      7647859.0  2021     12
# 3      7971480.0  2021     11
# 4      8103211.0  2021     10
# ..           ...   ...    ...
# 574          NaN  1974      4
# 575          NaN  1974      3
# 576          NaN  1974      2
# 577          NaN  1974      1
# 578    4898000.0  1973     12
#
# [579 rows x 3 columns]

# %%
storage_vol_df.isnull().sum()
# Out:
# Volume_Mmcf    18
# Year            0
# Month           0
# dtype: int64

# %%
storage_vol_df = pd.DataFrame(data=storage_vol_df, columns=["Year","Month","Volume_Mmcf"])
storage_vol_df
# Out:
#      Year  Month  Volume_Mmcf
# 0    2022      2    5997164.0
# 1    2022      1    6653327.0
# 2    2021     12    7647859.0
# 3    2021     11    7971480.0
# 4    2021     10    8103211.0
# ..    ...    ...          ...
# 574  1974      4          NaN
# 575  1974      3          NaN
# 576  1974      2          NaN
# 577  1974      1          NaN
# 578  1973     12    4898000.0
#
# [579 rows x 3 columns]

# %%
storage_vol_df = storage_vol_df[(storage_vol_df.Year >= int(2001))]
storage_vol_df
# Out:
#      Year  Month  Volume_Mmcf
# 0    2022      2    5997164.0
# 1    2022      1    6653327.0
# 2    2021     12    7647859.0
# 3    2021     11    7971480.0
# 4    2021     10    8103211.0
# ..    ...    ...          ...
# 249  2001      5    5749464.0
# 250  2001      4    5252851.0
# 251  2001      3    5041971.0
# 252  2001      2    5240820.0
# 253  2001      1    5609446.0
#
# [254 rows x 3 columns]

# %%
import os
storage_vol_df.to_csv('Resources/storage_vol.csv', index=False)

# %% [markdown]
# # What should we do for the NaN rows?

# %% [markdown]
# # Merge Gas Price by Type datasets into 1

# %%
import pandas as pd

# %%
price_by_type = pd.read_csv('Resources/PET_PRI_GND_DCUS_NUS_M.csv',skiprows=2)
price_by_type.head(10)
# Out:
#        Date  \
# 0  Aug-1990
# 1  Sep-1990
# 2  Oct-1990
# 3  Nov-1990
# 4  Dec-1990
# 5  Jan-1991
# 6  Feb-1991
# 7  Mar-1991
# 8  Apr-1991
# 9  May-1991
#
#    U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. All Grades Conventional Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. All Grades Reformulated Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                              1.258
# 2                                              1.335
# 3                                              1.324
# 4                                                NaN
# 5                                                NaN
# 6                                              1.094
# 7                                              1.040
# 8                                              1.076
# 9                                              1.126
#
#    U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                              1.258
# 2                                              1.335
# 3                                              1.324
# 4                                                NaN
# 5                                                NaN
# 6                                              1.094
# 7                                              1.040
# 8                                              1.076
# 9                                              1.126
#
#    U.S. Regular Reformulated Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Midgrade Conventional Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Midgrade Reformulated Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Premium Conventional Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. Premium Reformulated Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. No 2 Diesel Retail Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. No 2 Diesel Ultra Low Sulfur (0-15 ppm) Retail Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    U.S. No 2 Diesel Low Sulfur (15-500 ppm) Retail Prices (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %%
price_by_type.columns
# Out:
# Index(['Date',
#        'U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. All Grades Conventional Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. All Grades Reformulated Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Regular Reformulated Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Midgrade Conventional Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Midgrade Reformulated Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Premium Conventional Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Premium Reformulated Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. No 2 Diesel Retail Prices (Dollars per Gallon)',
#        'U.S. No 2 Diesel Ultra Low Sulfur (0-15 ppm) Retail Prices (Dollars per Gallon)',
#        'U.S. No 2 Diesel Low Sulfur (15-500 ppm) Retail Prices (Dollars per Gallon)',
#        'Unnamed: 16'],
#       dtype='object')

# %%
price_by_type = price_by_type.drop(columns=["U.S. All Grades Conventional Retail Gasoline Prices (Dollars per Gallon)",
    'U.S. All Grades Reformulated Retail Gasoline Prices (Dollars per Gallon)',
    'U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)',
       'U.S. Regular Reformulated Retail Gasoline Prices (Dollars per Gallon)',
    'U.S. Midgrade Conventional Retail Gasoline Prices (Dollars per Gallon)',
       'U.S. Midgrade Reformulated Retail Gasoline Prices (Dollars per Gallon)',
    'U.S. Premium Conventional Retail Gasoline Prices (Dollars per Gallon)',
       'U.S. Premium Reformulated Retail Gasoline Prices (Dollars per Gallon)',
    'U.S. No 2 Diesel Ultra Low Sulfur (0-15 ppm) Retail Prices (Dollars per Gallon)',
       'U.S. No 2 Diesel Low Sulfur (15-500 ppm) Retail Prices (Dollars per Gallon)',
       'Unnamed: 16'])
price_by_type
# Out:
#          Date  \
# 0    Aug-1990
# 1    Sep-1990
# 2    Oct-1990
# 3    Nov-1990
# 4    Dec-1990
# ..        ...
# 377  Jan-2022
# 378  Feb-2022
# 379  Mar-2022
# 380  Apr-2022
# 381       NaN
#
#      U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 377                                              3.413
# 378                                              3.611
# 379                                              4.322
# 380                                              4.213
# 381                                                NaN
#
#      U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                  NaN
# 1                                                1.258
# 2                                                1.335
# 3                                                1.324
# 4                                                  NaN
# ..                                                 ...
# 377                                              3.315
# 378                                              3.517
# 379                                              4.222
# 380                                              4.109
# 381                                                NaN
#
#      U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 377                                              3.766
# 378                                              3.939
# 379                                              4.681
# 380                                              4.598
# 381                                                NaN
#
#      U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 377                                              4.036
# 378                                              4.210
# 379                                              4.953
# 380                                              4.871
# 381                                                NaN
#
#      U.S. No 2 Diesel Retail Prices (Dollars per Gallon)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 377                                              3.724
# 378                                              4.032
# 379                                              5.105
# 380                                              5.120
# 381                                                NaN
#
# [382 rows x 6 columns]

# %%
price_by_type.columns
# Out:
# Index(['Date',
#        'U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)',
#        'U.S. No 2 Diesel Retail Prices (Dollars per Gallon)'],
#       dtype='object')

# %%
price_by_type=price_by_type.rename(columns={"Date":"Period",
        "U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)":"all_grades(Price_per_Gallon)",
        "U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)":"regular(Price_per_Gallon)",
        "U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)":"midgrade(Price_per_Gallon)",
        "U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)":"premium(Price_per_Gallon)",
        "U.S. No 2 Diesel Retail Prices (Dollars per Gallon)":"diesel(Price_per_Gallon)"})
price_by_type
# Out:
#        Period  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    Aug-1990                           NaN                        NaN
# 1    Sep-1990                           NaN                      1.258
# 2    Oct-1990                           NaN                      1.335
# 3    Nov-1990                           NaN                      1.324
# 4    Dec-1990                           NaN                        NaN
# ..        ...                           ...                        ...
# 377  Jan-2022                         3.413                      3.315
# 378  Feb-2022                         3.611                      3.517
# 379  Mar-2022                         4.322                      4.222
# 380  Apr-2022                         4.213                      4.109
# 381       NaN                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
# 381                       NaN
#
# [382 rows x 6 columns]

# %%
price_by_type["Date"] = pd.to_datetime(price_by_type["Period"])
price_by_type
# Out:
#        Period  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    Aug-1990                           NaN                        NaN
# 1    Sep-1990                           NaN                      1.258
# 2    Oct-1990                           NaN                      1.335
# 3    Nov-1990                           NaN                      1.324
# 4    Dec-1990                           NaN                        NaN
# ..        ...                           ...                        ...
# 377  Jan-2022                         3.413                      3.315
# 378  Feb-2022                         3.611                      3.517
# 379  Mar-2022                         4.322                      4.222
# 380  Apr-2022                         4.213                      4.109
# 381       NaN                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)       Date
# 0                         NaN 1990-08-01
# 1                         NaN 1990-09-01
# 2                         NaN 1990-10-01
# 3                         NaN 1990-11-01
# 4                         NaN 1990-12-01
# ..                        ...        ...
# 377                     3.724 2022-01-01
# 378                     4.032 2022-02-01
# 379                     5.105 2022-03-01
# 380                     5.120 2022-04-01
# 381                       NaN        NaT
#
# [382 rows x 7 columns]

# %%
price_by_type = price_by_type.drop(columns="Period")
price_by_type
# Out:
#      all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0                             NaN                        NaN
# 1                             NaN                      1.258
# 2                             NaN                      1.335
# 3                             NaN                      1.324
# 4                             NaN                        NaN
# ..                            ...                        ...
# 377                         3.413                      3.315
# 378                         3.611                      3.517
# 379                         4.322                      4.222
# 380                         4.213                      4.109
# 381                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)       Date
# 0                         NaN 1990-08-01
# 1                         NaN 1990-09-01
# 2                         NaN 1990-10-01
# 3                         NaN 1990-11-01
# 4                         NaN 1990-12-01
# ..                        ...        ...
# 377                     3.724 2022-01-01
# 378                     4.032 2022-02-01
# 379                     5.105 2022-03-01
# 380                     5.120 2022-04-01
# 381                       NaN        NaT
#
# [382 rows x 6 columns]

# %%
price_by_type= pd.DataFrame(data =price_by_type,
                                        columns={'Date':'Date',
                                                "all_grades(Price_per_Gallon)":"all_grades(Price_per_Gallon)",
        "regular(Price_per_Gallon)":"regular(Price_per_Gallon)",
        "midgrade(Price_per_Gallon)":"midgrade(Price_per_Gallon)",
        "premium(Price_per_Gallon)":"premium(Price_per_Gallon)",
        "diesel(Price_per_Gallon)":"diesel(Price_per_Gallon)"})
price_by_type
# Out:
#           Date  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0   1990-08-01                           NaN                        NaN
# 1   1990-09-01                           NaN                      1.258
# 2   1990-10-01                           NaN                      1.335
# 3   1990-11-01                           NaN                      1.324
# 4   1990-12-01                           NaN                        NaN
# ..         ...                           ...                        ...
# 377 2022-01-01                         3.413                      3.315
# 378 2022-02-01                         3.611                      3.517
# 379 2022-03-01                         4.322                      4.222
# 380 2022-04-01                         4.213                      4.109
# 381        NaT                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
# 381                       NaN
#
# [382 rows x 6 columns]

# %%
price_by_type['Year'] = price_by_type['Date'].dt.year
price_by_type['Month'] = price_by_type['Date'].dt.month
price_by_type
# Out:
#           Date  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0   1990-08-01                           NaN                        NaN
# 1   1990-09-01                           NaN                      1.258
# 2   1990-10-01                           NaN                      1.335
# 3   1990-11-01                           NaN                      1.324
# 4   1990-12-01                           NaN                        NaN
# ..         ...                           ...                        ...
# 377 2022-01-01                         3.413                      3.315
# 378 2022-02-01                         3.611                      3.517
# 379 2022-03-01                         4.322                      4.222
# 380 2022-04-01                         4.213                      4.109
# 381        NaT                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)    Year  Month
# 0                         NaN  1990.0    8.0
# 1                         NaN  1990.0    9.0
# 2                         NaN  1990.0   10.0
# 3                         NaN  1990.0   11.0
# 4                         NaN  1990.0   12.0
# ..                        ...     ...    ...
# 377                     3.724  2022.0    1.0
# 378                     4.032  2022.0    2.0
# 379                     5.105  2022.0    3.0
# 380                     5.120  2022.0    4.0
# 381                       NaN     NaN    NaN
#
# [382 rows x 8 columns]

# %%
price_by_type = price_by_type.drop(columns="Date")
price_by_type
# Out:
#      all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0                             NaN                        NaN
# 1                             NaN                      1.258
# 2                             NaN                      1.335
# 3                             NaN                      1.324
# 4                             NaN                        NaN
# ..                            ...                        ...
# 377                         3.413                      3.315
# 378                         3.611                      3.517
# 379                         4.322                      4.222
# 380                         4.213                      4.109
# 381                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)    Year  Month
# 0                         NaN  1990.0    8.0
# 1                         NaN  1990.0    9.0
# 2                         NaN  1990.0   10.0
# 3                         NaN  1990.0   11.0
# 4                         NaN  1990.0   12.0
# ..                        ...     ...    ...
# 377                     3.724  2022.0    1.0
# 378                     4.032  2022.0    2.0
# 379                     5.105  2022.0    3.0
# 380                     5.120  2022.0    4.0
# 381                       NaN     NaN    NaN
#
# [382 rows x 7 columns]

# %%
price_by_type= pd.DataFrame(data =price_by_type,
                                        columns={'Year':'Year','Month':'Month',
                                                "all_grades(Price_per_Gallon)":"all_grades(Price_per_Gallon)",
        "regular(Price_per_Gallon)":"regular(Price_per_Gallon)",
        "midgrade(Price_per_Gallon)":"midgrade(Price_per_Gallon)",
        "premium(Price_per_Gallon)":"premium(Price_per_Gallon)",
        "diesel(Price_per_Gallon)":"diesel(Price_per_Gallon)"})
price_by_type
# Out:
#        Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    1990.0    8.0                           NaN                        NaN
# 1    1990.0    9.0                           NaN                      1.258
# 2    1990.0   10.0                           NaN                      1.335
# 3    1990.0   11.0                           NaN                      1.324
# 4    1990.0   12.0                           NaN                        NaN
# ..      ...    ...                           ...                        ...
# 377  2022.0    1.0                         3.413                      3.315
# 378  2022.0    2.0                         3.611                      3.517
# 379  2022.0    3.0                         4.322                      4.222
# 380  2022.0    4.0                         4.213                      4.109
# 381     NaN    NaN                           NaN                        NaN
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
# 381                         NaN                        NaN
#
#      diesel(Price_per_Gallon)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
# 381                       NaN
#
# [382 rows x 7 columns]

# %%
price_by_type.dtypes
# Out:
# Year                            float64
# Month                           float64
# all_grades(Price_per_Gallon)    float64
# regular(Price_per_Gallon)       float64
# midgrade(Price_per_Gallon)      float64
# premium(Price_per_Gallon)       float64
# diesel(Price_per_Gallon)        float64
# dtype: object

# %%
price_by_type=price_by_type[:381]
price_by_type
# Out:
#        Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    1990.0    8.0                           NaN                        NaN
# 1    1990.0    9.0                           NaN                      1.258
# 2    1990.0   10.0                           NaN                      1.335
# 3    1990.0   11.0                           NaN                      1.324
# 4    1990.0   12.0                           NaN                        NaN
# ..      ...    ...                           ...                        ...
# 376  2021.0   12.0                         3.406                      3.307
# 377  2022.0    1.0                         3.413                      3.315
# 378  2022.0    2.0                         3.611                      3.517
# 379  2022.0    3.0                         4.322                      4.222
# 380  2022.0    4.0                         4.213                      4.109
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 376                       3.771                      4.034
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
#
#      diesel(Price_per_Gallon)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 376                     3.641
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
#
# [381 rows x 7 columns]

# %%
price_by_type['Year'] = price_by_type['Year'].astype(int)
price_by_type['Month'] = price_by_type['Month'].astype(int)
price_by_type
# Out:
# C:\Users\kimbe\AppData\Local\Temp/ipykernel_12292/2329566930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_by_type['Year'] = price_by_type['Year'].astype(int)
# C:\Users\kimbe\AppData\Local\Temp/ipykernel_12292/2329566930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_by_type['Month'] = price_by_type['Month'].astype(int)
#      Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    1990      8                           NaN                        NaN
# 1    1990      9                           NaN                      1.258
# 2    1990     10                           NaN                      1.335
# 3    1990     11                           NaN                      1.324
# 4    1990     12                           NaN                        NaN
# ..    ...    ...                           ...                        ...
# 376  2021     12                         3.406                      3.307
# 377  2022      1                         3.413                      3.315
# 378  2022      2                         3.611                      3.517
# 379  2022      3                         4.322                      4.222
# 380  2022      4                         4.213                      4.109
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 376                       3.771                      4.034
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
#
#      diesel(Price_per_Gallon)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 376                     3.641
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
#
# [381 rows x 7 columns]

# %%
price_by_type = price_by_type[(price_by_type.Year >= int(2001))]
price_by_type
# Out:
#      Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 125  2001      1                         1.487                      1.447
# 126  2001      2                         1.490                      1.450
# 127  2001      3                         1.450                      1.409
# 128  2001      4                         1.591                      1.552
# 129  2001      5                         1.738                      1.702
# ..    ...    ...                           ...                        ...
# 376  2021     12                         3.406                      3.307
# 377  2022      1                         3.413                      3.315
# 378  2022      2                         3.611                      3.517
# 379  2022      3                         4.322                      4.222
# 380  2022      4                         4.213                      4.109
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 125                       1.541                      1.630
# 126                       1.544                      1.635
# 127                       1.506                      1.596
# 128                       1.646                      1.732
# 129                       1.785                      1.869
# ..                          ...                        ...
# 376                       3.771                      4.034
# 377                       3.766                      4.036
# 378                       3.939                      4.210
# 379                       4.681                      4.953
# 380                       4.598                      4.871
#
#      diesel(Price_per_Gallon)
# 125                     1.524
# 126                     1.492
# 127                     1.399
# 128                     1.422
# 129                     1.496
# ..                        ...
# 376                     3.641
# 377                     3.724
# 378                     4.032
# 379                     5.105
# 380                     5.120
#
# [256 rows x 7 columns]

# %%
price_by_type = price_by_type.reset_index()
price_by_type
# Out:
#      index  Year  Month  all_grades(Price_per_Gallon)  \
# 0      125  2001      1                         1.487
# 1      126  2001      2                         1.490
# 2      127  2001      3                         1.450
# 3      128  2001      4                         1.591
# 4      129  2001      5                         1.738
# ..     ...   ...    ...                           ...
# 251    376  2021     12                         3.406
# 252    377  2022      1                         3.413
# 253    378  2022      2                         3.611
# 254    379  2022      3                         4.322
# 255    380  2022      4                         4.213
#
#      regular(Price_per_Gallon)  midgrade(Price_per_Gallon)  \
# 0                        1.447                       1.541
# 1                        1.450                       1.544
# 2                        1.409                       1.506
# 3                        1.552                       1.646
# 4                        1.702                       1.785
# ..                         ...                         ...
# 251                      3.307                       3.771
# 252                      3.315                       3.766
# 253                      3.517                       3.939
# 254                      4.222                       4.681
# 255                      4.109                       4.598
#
#      premium(Price_per_Gallon)  diesel(Price_per_Gallon)
# 0                        1.630                     1.524
# 1                        1.635                     1.492
# 2                        1.596                     1.399
# 3                        1.732                     1.422
# 4                        1.869                     1.496
# ..                         ...                       ...
# 251                      4.034                     3.641
# 252                      4.036                     3.724
# 253                      4.210                     4.032
# 254                      4.953                     5.105
# 255                      4.871                     5.120
#
# [256 rows x 8 columns]

# %%
price_by_type = price_by_type.drop(columns="index")
price_by_type
# Out:
#      Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    2001      1                         1.487                      1.447
# 1    2001      2                         1.490                      1.450
# 2    2001      3                         1.450                      1.409
# 3    2001      4                         1.591                      1.552
# 4    2001      5                         1.738                      1.702
# ..    ...    ...                           ...                        ...
# 251  2021     12                         3.406                      3.307
# 252  2022      1                         3.413                      3.315
# 253  2022      2                         3.611                      3.517
# 254  2022      3                         4.322                      4.222
# 255  2022      4                         4.213                      4.109
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                         1.541                      1.630
# 1                         1.544                      1.635
# 2                         1.506                      1.596
# 3                         1.646                      1.732
# 4                         1.785                      1.869
# ..                          ...                        ...
# 251                       3.771                      4.034
# 252                       3.766                      4.036
# 253                       3.939                      4.210
# 254                       4.681                      4.953
# 255                       4.598                      4.871
#
#      diesel(Price_per_Gallon)
# 0                       1.524
# 1                       1.492
# 2                       1.399
# 3                       1.422
# 4                       1.496
# ..                        ...
# 251                     3.641
# 252                     3.724
# 253                     4.032
# 254                     5.105
# 255                     5.120
#
# [256 rows x 7 columns]

# %%
price_by_type = price_by_type[:254]
price_by_type
# Out:
#      Year  Month  all_grades(Price_per_Gallon)  regular(Price_per_Gallon)  \
# 0    2001      1                         1.487                      1.447
# 1    2001      2                         1.490                      1.450
# 2    2001      3                         1.450                      1.409
# 3    2001      4                         1.591                      1.552
# 4    2001      5                         1.738                      1.702
# ..    ...    ...                           ...                        ...
# 249  2021     10                         3.384                      3.291
# 250  2021     11                         3.491                      3.395
# 251  2021     12                         3.406                      3.307
# 252  2022      1                         3.413                      3.315
# 253  2022      2                         3.611                      3.517
#
#      midgrade(Price_per_Gallon)  premium(Price_per_Gallon)  \
# 0                         1.541                      1.630
# 1                         1.544                      1.635
# 2                         1.506                      1.596
# 3                         1.646                      1.732
# 4                         1.785                      1.869
# ..                          ...                        ...
# 249                       3.723                      3.979
# 250                       3.836                      4.098
# 251                       3.771                      4.034
# 252                       3.766                      4.036
# 253                       3.939                      4.210
#
#      diesel(Price_per_Gallon)
# 0                       1.524
# 1                       1.492
# 2                       1.399
# 3                       1.422
# 4                       1.496
# ..                        ...
# 249                     3.612
# 250                     3.727
# 251                     3.641
# 252                     3.724
# 253                     4.032
#
# [254 rows x 7 columns]

# %%
import os
price_by_type.to_csv('Resources/price_by_type.csv', index=False)
