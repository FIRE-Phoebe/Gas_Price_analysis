# %% [markdown]
# # More Data Cleaning

# %% [markdown]
# ## Interest Rate - US Data

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
interest_rate_us = pd.read_csv('Resources/Datasets/INTDSRUSM193N.csv')
interest_rate_us
# Out:
#          DATE  INTDSRUSM193N
# 0    1/1/2001           5.52
# 1    2/1/2001           5.00
# 2    3/1/2001           4.81
# 3    4/1/2001           4.28
# 4    5/1/2001           3.73
# ..        ...            ...
# 243  4/1/2021           0.25
# 244  5/1/2021           0.25
# 245  6/1/2021           0.25
# 246  7/1/2021           0.25
# 247  8/1/2021           0.25
#
# [248 rows x 2 columns]

# %%
interest_rate_us.columns
# Out:
# Index(['DATE', 'INTDSRUSM193N'], dtype='object')

# %%
interest_rate_us.dtypes
# Out:
# DATE              object
# INTDSRUSM193N    float64
# dtype: object

# %%
interest_rate_us["Date"] = pd.to_datetime(interest_rate_us["DATE"])
interest_rate_us.head()
# Out:
#        DATE  INTDSRUSM193N       Date
# 0  1/1/2001           5.52 2001-01-01
# 1  2/1/2001           5.00 2001-02-01
# 2  3/1/2001           4.81 2001-03-01
# 3  4/1/2001           4.28 2001-04-01
# 4  5/1/2001           3.73 2001-05-01

# %%
interest_rate_us= interest_rate_us.drop(["DATE"],axis=1)
interest_rate_us
# Out:
#      INTDSRUSM193N       Date
# 0             5.52 2001-01-01
# 1             5.00 2001-02-01
# 2             4.81 2001-03-01
# 3             4.28 2001-04-01
# 4             3.73 2001-05-01
# ..             ...        ...
# 243           0.25 2021-04-01
# 244           0.25 2021-05-01
# 245           0.25 2021-06-01
# 246           0.25 2021-07-01
# 247           0.25 2021-08-01
#
# [248 rows x 2 columns]

# %%
interest_rate_us = pd.DataFrame(data=interest_rate_us, columns={'Date',"INTDSRUSM193N"})
interest_rate_us
# Out:
#           Date  INTDSRUSM193N
# 0   2001-01-01           5.52
# 1   2001-02-01           5.00
# 2   2001-03-01           4.81
# 3   2001-04-01           4.28
# 4   2001-05-01           3.73
# ..         ...            ...
# 243 2021-04-01           0.25
# 244 2021-05-01           0.25
# 245 2021-06-01           0.25
# 246 2021-07-01           0.25
# 247 2021-08-01           0.25
#
# [248 rows x 2 columns]

# %%
interest_rate_us['Year'] = interest_rate_us['Date'].dt.year
interest_rate_us['Month'] = interest_rate_us['Date'].dt.month
interest_rate_us
# Out:
#           Date  INTDSRUSM193N  Year  Month
# 0   2001-01-01           5.52  2001      1
# 1   2001-02-01           5.00  2001      2
# 2   2001-03-01           4.81  2001      3
# 3   2001-04-01           4.28  2001      4
# 4   2001-05-01           3.73  2001      5
# ..         ...            ...   ...    ...
# 243 2021-04-01           0.25  2021      4
# 244 2021-05-01           0.25  2021      5
# 245 2021-06-01           0.25  2021      6
# 246 2021-07-01           0.25  2021      7
# 247 2021-08-01           0.25  2021      8
#
# [248 rows x 4 columns]

# %%
interest_rate_us= interest_rate_us.drop(["Date"],axis=1)
interest_rate_us
# Out:
#      INTDSRUSM193N  Year  Month
# 0             5.52  2001      1
# 1             5.00  2001      2
# 2             4.81  2001      3
# 3             4.28  2001      4
# 4             3.73  2001      5
# ..             ...   ...    ...
# 243           0.25  2021      4
# 244           0.25  2021      5
# 245           0.25  2021      6
# 246           0.25  2021      7
# 247           0.25  2021      8
#
# [248 rows x 3 columns]

# %%
interest_rate_us = pd.DataFrame(data=interest_rate_us, columns=['Year','Month',"INTDSRUSM193N"])
interest_rate_us
# Out:
#      Year  Month  INTDSRUSM193N
# 0    2001      1           5.52
# 1    2001      2           5.00
# 2    2001      3           4.81
# 3    2001      4           4.28
# 4    2001      5           3.73
# ..    ...    ...            ...
# 243  2021      4           0.25
# 244  2021      5           0.25
# 245  2021      6           0.25
# 246  2021      7           0.25
# 247  2021      8           0.25
#
# [248 rows x 3 columns]

# %%
interest_rate_us= interest_rate_us.rename(columns={"Year":"Year", "Month":"Month",
        "INTDSRUSM193N":"Interest_Rate(%)"})
interest_rate_us
# Out:
#      Year  Month  Interest_Rate(%)
# 0    2001      1              5.52
# 1    2001      2              5.00
# 2    2001      3              4.81
# 3    2001      4              4.28
# 4    2001      5              3.73
# ..    ...    ...               ...
# 243  2021      4              0.25
# 244  2021      5              0.25
# 245  2021      6              0.25
# 246  2021      7              0.25
# 247  2021      8              0.25
#
# [248 rows x 3 columns]

# %%
interest_rate_yearly = interest_rate_us.groupby(['Year']).mean()
interest_rate_yearly
# Out:
#       Month  Interest_Rate(%)
# Year
# 2001    6.5          3.410000
# 2002    6.5          1.173333
# 2003    6.5          2.104167
# 2004    6.5          2.395833
# 2005    6.5          4.250000
# 2006    6.5          6.020833
# 2007    6.5          5.791667
# 2008    6.5          2.166667
# 2009    6.5          0.500000
# 2010    6.5          0.729167
# 2011    6.5          0.750000
# 2012    6.5          0.750000
# 2013    6.5          0.750000
# 2014    6.5          0.750000
# 2015    6.5          0.770833
# 2016    6.5          1.020833
# 2017    6.5          1.625000
# 2018    6.5          2.458333
# 2019    6.5          2.750000
# 2020    6.5          0.583333
# 2021    4.5          0.250000

# %%
interest_rate_yearly = interest_rate_yearly.reset_index()
interest_rate_yearly
# Out:
#     Year  Month  Interest_Rate(%)
# 0   2001    6.5          3.410000
# 1   2002    6.5          1.173333
# 2   2003    6.5          2.104167
# 3   2004    6.5          2.395833
# 4   2005    6.5          4.250000
# 5   2006    6.5          6.020833
# 6   2007    6.5          5.791667
# 7   2008    6.5          2.166667
# 8   2009    6.5          0.500000
# 9   2010    6.5          0.729167
# 10  2011    6.5          0.750000
# 11  2012    6.5          0.750000
# 12  2013    6.5          0.750000
# 13  2014    6.5          0.750000
# 14  2015    6.5          0.770833
# 15  2016    6.5          1.020833
# 16  2017    6.5          1.625000
# 17  2018    6.5          2.458333
# 18  2019    6.5          2.750000
# 19  2020    6.5          0.583333
# 20  2021    4.5          0.250000

# %%
interest_rate_yearly = interest_rate_yearly.drop(columns='Month')
interest_rate_yearly
# Out:
#     Year  Interest_Rate(%)
# 0   2001          3.410000
# 1   2002          1.173333
# 2   2003          2.104167
# 3   2004          2.395833
# 4   2005          4.250000
# 5   2006          6.020833
# 6   2007          5.791667
# 7   2008          2.166667
# 8   2009          0.500000
# 9   2010          0.729167
# 10  2011          0.750000
# 11  2012          0.750000
# 12  2013          0.750000
# 13  2014          0.750000
# 14  2015          0.770833
# 15  2016          1.020833
# 16  2017          1.625000
# 17  2018          2.458333
# 18  2019          2.750000
# 19  2020          0.583333
# 20  2021          0.250000

# %% [markdown]
# ## Working population data

# %%
working_pop = pd.read_csv('Resources/Datasets/LFWA64TTUSM647S.csv')
working_pop
# Out:
#           DATE  LFWA64TTUSM647S
# 0     1/1/2001      180406010.5
# 1     2/1/2001      180564078.8
# 2     3/1/2001      180627181.6
# 3     4/1/2001      180903832.3
# 4     5/1/2001      181015684.9
# ..         ...              ...
# 251  12/1/2021      205161455.9
# 252   1/1/2022      207145172.9
# 253   2/1/2022      207124343.6
# 254   3/1/2022      206950351.2
# 255   4/1/2022      207092091.1
#
# [256 rows x 2 columns]

# %%
working_pop["Date"] = pd.to_datetime(working_pop["DATE"])
working_pop.head()
# Out:
#        DATE  LFWA64TTUSM647S       Date
# 0  1/1/2001      180406010.5 2001-01-01
# 1  2/1/2001      180564078.8 2001-02-01
# 2  3/1/2001      180627181.6 2001-03-01
# 3  4/1/2001      180903832.3 2001-04-01
# 4  5/1/2001      181015684.9 2001-05-01

# %%
working_pop= working_pop.drop(["DATE"],axis=1)
working_pop
# Out:
#      LFWA64TTUSM647S       Date
# 0        180406010.5 2001-01-01
# 1        180564078.8 2001-02-01
# 2        180627181.6 2001-03-01
# 3        180903832.3 2001-04-01
# 4        181015684.9 2001-05-01
# ..               ...        ...
# 251      205161455.9 2021-12-01
# 252      207145172.9 2022-01-01
# 253      207124343.6 2022-02-01
# 254      206950351.2 2022-03-01
# 255      207092091.1 2022-04-01
#
# [256 rows x 2 columns]

# %%
working_pop = pd.DataFrame(data=working_pop, columns={'Date',"LFWA64TTUSM647S"})
working_pop
# Out:
#           Date  LFWA64TTUSM647S
# 0   2001-01-01      180406010.5
# 1   2001-02-01      180564078.8
# 2   2001-03-01      180627181.6
# 3   2001-04-01      180903832.3
# 4   2001-05-01      181015684.9
# ..         ...              ...
# 251 2021-12-01      205161455.9
# 252 2022-01-01      207145172.9
# 253 2022-02-01      207124343.6
# 254 2022-03-01      206950351.2
# 255 2022-04-01      207092091.1
#
# [256 rows x 2 columns]

# %%
working_pop['Year'] = working_pop['Date'].dt.year
working_pop['Month'] = working_pop['Date'].dt.month
working_pop
# Out:
#           Date  LFWA64TTUSM647S  Year  Month
# 0   2001-01-01      180406010.5  2001      1
# 1   2001-02-01      180564078.8  2001      2
# 2   2001-03-01      180627181.6  2001      3
# 3   2001-04-01      180903832.3  2001      4
# 4   2001-05-01      181015684.9  2001      5
# ..         ...              ...   ...    ...
# 251 2021-12-01      205161455.9  2021     12
# 252 2022-01-01      207145172.9  2022      1
# 253 2022-02-01      207124343.6  2022      2
# 254 2022-03-01      206950351.2  2022      3
# 255 2022-04-01      207092091.1  2022      4
#
# [256 rows x 4 columns]

# %%
working_pop= working_pop.drop(["Date"],axis=1)
working_pop
# Out:
#      LFWA64TTUSM647S  Year  Month
# 0        180406010.5  2001      1
# 1        180564078.8  2001      2
# 2        180627181.6  2001      3
# 3        180903832.3  2001      4
# 4        181015684.9  2001      5
# ..               ...   ...    ...
# 251      205161455.9  2021     12
# 252      207145172.9  2022      1
# 253      207124343.6  2022      2
# 254      206950351.2  2022      3
# 255      207092091.1  2022      4
#
# [256 rows x 3 columns]

# %%
working_pop.columns
# Out:
# Index(['LFWA64TTUSM647S', 'Year', 'Month'], dtype='object')

# %%
working_pop = pd.DataFrame(data=working_pop, columns=['Year','Month',"LFWA64TTUSM647S"])
working_pop
# Out:
#      Year  Month  LFWA64TTUSM647S
# 0    2001      1      180406010.5
# 1    2001      2      180564078.8
# 2    2001      3      180627181.6
# 3    2001      4      180903832.3
# 4    2001      5      181015684.9
# ..    ...    ...              ...
# 251  2021     12      205161455.9
# 252  2022      1      207145172.9
# 253  2022      2      207124343.6
# 254  2022      3      206950351.2
# 255  2022      4      207092091.1
#
# [256 rows x 3 columns]

# %%
working_pop= working_pop.rename(columns={"Year":"Year", "Month":"Month",
        "LFWA64TTUSM647S":"working_population"})
working_pop
# Out:
#      Year  Month  working_population
# 0    2001      1         180406010.5
# 1    2001      2         180564078.8
# 2    2001      3         180627181.6
# 3    2001      4         180903832.3
# 4    2001      5         181015684.9
# ..    ...    ...                 ...
# 251  2021     12         205161455.9
# 252  2022      1         207145172.9
# 253  2022      2         207124343.6
# 254  2022      3         206950351.2
# 255  2022      4         207092091.1
#
# [256 rows x 3 columns]

# %%
working_pop_yearly = working_pop.groupby(['Year']).mean()
working_pop_yearly
# Out:
#       Month  working_population
# Year
# 2001    6.5        1.814766e+08
# 2002    6.5        1.837927e+08
# 2003    6.5        1.869398e+08
# 2004    6.5        1.887631e+08
# 2005    6.5        1.910250e+08
# 2006    6.5        1.932194e+08
# 2007    6.5        1.956636e+08
# 2008    6.5        1.966915e+08
# 2009    6.5        1.978975e+08
# 2010    6.5        1.991838e+08
# 2011    6.5        1.999626e+08
# 2012    6.5        2.014758e+08
# 2013    6.5        2.023276e+08
# 2014    6.5        2.030205e+08
# 2015    6.5        2.043341e+08
# 2016    6.5        2.055540e+08
# 2017    6.5        2.055702e+08
# 2018    6.5        2.065389e+08
# 2019    6.5        2.063096e+08
# 2020    6.5        2.059544e+08
# 2021    6.5        2.052735e+08
# 2022    2.5        2.070780e+08

# %%
working_pop_yearly= working_pop_yearly.reset_index()
working_pop_yearly
# Out:
#     Year  Month  working_population
# 0   2001    6.5        1.814766e+08
# 1   2002    6.5        1.837927e+08
# 2   2003    6.5        1.869398e+08
# 3   2004    6.5        1.887631e+08
# 4   2005    6.5        1.910250e+08
# 5   2006    6.5        1.932194e+08
# 6   2007    6.5        1.956636e+08
# 7   2008    6.5        1.966915e+08
# 8   2009    6.5        1.978975e+08
# 9   2010    6.5        1.991838e+08
# 10  2011    6.5        1.999626e+08
# 11  2012    6.5        2.014758e+08
# 12  2013    6.5        2.023276e+08
# 13  2014    6.5        2.030205e+08
# 14  2015    6.5        2.043341e+08
# 15  2016    6.5        2.055540e+08
# 16  2017    6.5        2.055702e+08
# 17  2018    6.5        2.065389e+08
# 18  2019    6.5        2.063096e+08
# 19  2020    6.5        2.059544e+08
# 20  2021    6.5        2.052735e+08
# 21  2022    2.5        2.070780e+08

# %%
working_pop_yearly = working_pop_yearly.drop(columns='Month')
working_pop_yearly
# Out:
#     Year  working_population
# 0   2001        1.814766e+08
# 1   2002        1.837927e+08
# 2   2003        1.869398e+08
# 3   2004        1.887631e+08
# 4   2005        1.910250e+08
# 5   2006        1.932194e+08
# 6   2007        1.956636e+08
# 7   2008        1.966915e+08
# 8   2009        1.978975e+08
# 9   2010        1.991838e+08
# 10  2011        1.999626e+08
# 11  2012        2.014758e+08
# 12  2013        2.023276e+08
# 13  2014        2.030205e+08
# 14  2015        2.043341e+08
# 15  2016        2.055540e+08
# 16  2017        2.055702e+08
# 17  2018        2.065389e+08
# 18  2019        2.063096e+08
# 19  2020        2.059544e+08
# 20  2021        2.052735e+08
# 21  2022        2.070780e+08

# %%
working_pop_yearly.dtypes
# Out:
# Year                    int64
# working_population    float64
# dtype: object

# %%
working_pop_yearly=working_pop_yearly.astype('int64')
working_pop_yearly
# Out:
#     Year  working_population
# 0   2001           181476647
# 1   2002           183792729
# 2   2003           186939817
# 3   2004           188763071
# 4   2005           191024953
# 5   2006           193219398
# 6   2007           195663562
# 7   2008           196691536
# 8   2009           197897475
# 9   2010           199183839
# 10  2011           199962562
# 11  2012           201475828
# 12  2013           202327635
# 13  2014           203020518
# 14  2015           204334050
# 15  2016           205553963
# 16  2017           205570247
# 17  2018           206538862
# 18  2019           206309620
# 19  2020           205954426
# 20  2021           205273525
# 21  2022           207077989

# %% [markdown]
# ## Stock market to GDP (%) data

# %%
stock_to_GDP_percent = pd.read_csv('Resources/Datasets/DDDM01USA156NWDB.csv')
stock_to_GDP_percent
# Out:
#         DATE  DDDM01USA156NWDB
# 0   1/1/2001          132.1480
# 1   1/1/2002          101.0791
# 2   1/1/2003          124.5066
# 3   1/1/2004          133.6506
# 4   1/1/2005          130.4083
# 5   1/1/2006          141.6542
# 6   1/1/2007          137.8527
# 7   1/1/2008           78.7766
# 8   1/1/2009          104.3488
# 9   1/1/2010          115.2841
# 10  1/1/2011          100.6313
# 11  1/1/2012          115.2579
# 12  1/1/2013          143.1937
# 13  1/1/2014          150.2273
# 14  1/1/2015          137.4445
# 15  1/1/2016          145.9167
# 16  1/1/2017          164.3593
# 17  1/1/2018          147.6641
# 18  1/1/2019          158.1229

# %%
stock_to_GDP_percent.loc[len(stock_to_GDP_percent.index)] = ['1/1/2020',194.490]
stock_to_GDP_percent
# Out:
#         DATE  DDDM01USA156NWDB
# 0   1/1/2001          132.1480
# 1   1/1/2002          101.0791
# 2   1/1/2003          124.5066
# 3   1/1/2004          133.6506
# 4   1/1/2005          130.4083
# 5   1/1/2006          141.6542
# 6   1/1/2007          137.8527
# 7   1/1/2008           78.7766
# 8   1/1/2009          104.3488
# 9   1/1/2010          115.2841
# 10  1/1/2011          100.6313
# 11  1/1/2012          115.2579
# 12  1/1/2013          143.1937
# 13  1/1/2014          150.2273
# 14  1/1/2015          137.4445
# 15  1/1/2016          145.9167
# 16  1/1/2017          164.3593
# 17  1/1/2018          147.6641
# 18  1/1/2019          158.1229
# 19  1/1/2020          194.4900

# %%
stock_to_GDP_percent["Date"] = pd.to_datetime(stock_to_GDP_percent["DATE"])
stock_to_GDP_percent.head()
# Out:
#        DATE  DDDM01USA156NWDB       Date
# 0  1/1/2001          132.1480 2001-01-01
# 1  1/1/2002          101.0791 2002-01-01
# 2  1/1/2003          124.5066 2003-01-01
# 3  1/1/2004          133.6506 2004-01-01
# 4  1/1/2005          130.4083 2005-01-01

# %%
stock_to_GDP_percent= stock_to_GDP_percent.drop(["DATE"],axis=1)
stock_to_GDP_percent
# Out:
#     DDDM01USA156NWDB       Date
# 0           132.1480 2001-01-01
# 1           101.0791 2002-01-01
# 2           124.5066 2003-01-01
# 3           133.6506 2004-01-01
# 4           130.4083 2005-01-01
# 5           141.6542 2006-01-01
# 6           137.8527 2007-01-01
# 7            78.7766 2008-01-01
# 8           104.3488 2009-01-01
# 9           115.2841 2010-01-01
# 10          100.6313 2011-01-01
# 11          115.2579 2012-01-01
# 12          143.1937 2013-01-01
# 13          150.2273 2014-01-01
# 14          137.4445 2015-01-01
# 15          145.9167 2016-01-01
# 16          164.3593 2017-01-01
# 17          147.6641 2018-01-01
# 18          158.1229 2019-01-01
# 19          194.4900 2020-01-01

# %%
stock_to_GDP_percent = pd.DataFrame(data=stock_to_GDP_percent, columns={'Date',"DDDM01USA156NWDB"})
stock_to_GDP_percent
# Out:
#          Date  DDDM01USA156NWDB
# 0  2001-01-01          132.1480
# 1  2002-01-01          101.0791
# 2  2003-01-01          124.5066
# 3  2004-01-01          133.6506
# 4  2005-01-01          130.4083
# 5  2006-01-01          141.6542
# 6  2007-01-01          137.8527
# 7  2008-01-01           78.7766
# 8  2009-01-01          104.3488
# 9  2010-01-01          115.2841
# 10 2011-01-01          100.6313
# 11 2012-01-01          115.2579
# 12 2013-01-01          143.1937
# 13 2014-01-01          150.2273
# 14 2015-01-01          137.4445
# 15 2016-01-01          145.9167
# 16 2017-01-01          164.3593
# 17 2018-01-01          147.6641
# 18 2019-01-01          158.1229
# 19 2020-01-01          194.4900

# %%
stock_to_GDP_percent['Year'] = stock_to_GDP_percent['Date'].dt.year
stock_to_GDP_percent['Month'] = stock_to_GDP_percent['Date'].dt.month
stock_to_GDP_percent
# Out:
#          Date  DDDM01USA156NWDB  Year  Month
# 0  2001-01-01          132.1480  2001      1
# 1  2002-01-01          101.0791  2002      1
# 2  2003-01-01          124.5066  2003      1
# 3  2004-01-01          133.6506  2004      1
# 4  2005-01-01          130.4083  2005      1
# 5  2006-01-01          141.6542  2006      1
# 6  2007-01-01          137.8527  2007      1
# 7  2008-01-01           78.7766  2008      1
# 8  2009-01-01          104.3488  2009      1
# 9  2010-01-01          115.2841  2010      1
# 10 2011-01-01          100.6313  2011      1
# 11 2012-01-01          115.2579  2012      1
# 12 2013-01-01          143.1937  2013      1
# 13 2014-01-01          150.2273  2014      1
# 14 2015-01-01          137.4445  2015      1
# 15 2016-01-01          145.9167  2016      1
# 16 2017-01-01          164.3593  2017      1
# 17 2018-01-01          147.6641  2018      1
# 18 2019-01-01          158.1229  2019      1
# 19 2020-01-01          194.4900  2020      1

# %%
stock_to_GDP_percent= stock_to_GDP_percent.drop(["Date"],axis=1)
stock_to_GDP_percent
# Out:
#     DDDM01USA156NWDB  Year  Month
# 0           132.1480  2001      1
# 1           101.0791  2002      1
# 2           124.5066  2003      1
# 3           133.6506  2004      1
# 4           130.4083  2005      1
# 5           141.6542  2006      1
# 6           137.8527  2007      1
# 7            78.7766  2008      1
# 8           104.3488  2009      1
# 9           115.2841  2010      1
# 10          100.6313  2011      1
# 11          115.2579  2012      1
# 12          143.1937  2013      1
# 13          150.2273  2014      1
# 14          137.4445  2015      1
# 15          145.9167  2016      1
# 16          164.3593  2017      1
# 17          147.6641  2018      1
# 18          158.1229  2019      1
# 19          194.4900  2020      1

# %%
stock_to_GDP_percent = pd.DataFrame(data=stock_to_GDP_percent, columns=['Year','Month',"DDDM01USA156NWDB"])
stock_to_GDP_percent
# Out:
#     Year  Month  DDDM01USA156NWDB
# 0   2001      1          132.1480
# 1   2002      1          101.0791
# 2   2003      1          124.5066
# 3   2004      1          133.6506
# 4   2005      1          130.4083
# 5   2006      1          141.6542
# 6   2007      1          137.8527
# 7   2008      1           78.7766
# 8   2009      1          104.3488
# 9   2010      1          115.2841
# 10  2011      1          100.6313
# 11  2012      1          115.2579
# 12  2013      1          143.1937
# 13  2014      1          150.2273
# 14  2015      1          137.4445
# 15  2016      1          145.9167
# 16  2017      1          164.3593
# 17  2018      1          147.6641
# 18  2019      1          158.1229
# 19  2020      1          194.4900

# %%
stock_to_GDP_percent= stock_to_GDP_percent.rename(columns={"Year":"Year", "Month":"Month",
        "DDDM01USA156NWDB":"stock_to_GDP(%)"})
stock_to_GDP_percent
# Out:
#     Year  Month  stock_to_GDP(%)
# 0   2001      1         132.1480
# 1   2002      1         101.0791
# 2   2003      1         124.5066
# 3   2004      1         133.6506
# 4   2005      1         130.4083
# 5   2006      1         141.6542
# 6   2007      1         137.8527
# 7   2008      1          78.7766
# 8   2009      1         104.3488
# 9   2010      1         115.2841
# 10  2011      1         100.6313
# 11  2012      1         115.2579
# 12  2013      1         143.1937
# 13  2014      1         150.2273
# 14  2015      1         137.4445
# 15  2016      1         145.9167
# 16  2017      1         164.3593
# 17  2018      1         147.6641
# 18  2019      1         158.1229
# 19  2020      1         194.4900

# %%
stock_to_GDP_percent_yearly = stock_to_GDP_percent.drop(columns='Month')
stock_to_GDP_percent_yearly
# Out:
#     Year  stock_to_GDP(%)
# 0   2001         132.1480
# 1   2002         101.0791
# 2   2003         124.5066
# 3   2004         133.6506
# 4   2005         130.4083
# 5   2006         141.6542
# 6   2007         137.8527
# 7   2008          78.7766
# 8   2009         104.3488
# 9   2010         115.2841
# 10  2011         100.6313
# 11  2012         115.2579
# 12  2013         143.1937
# 13  2014         150.2273
# 14  2015         137.4445
# 15  2016         145.9167
# 16  2017         164.3593
# 17  2018         147.6641
# 18  2019         158.1229
# 19  2020         194.4900

# %% [markdown]
# ## Inflation data

# %%
inflation = pd.read_csv('Resources/Datasets/FPCPITOTLZGUSA.csv')
inflation
# Out:
#         DATE  FPCPITOTLZGUSA
# 0   1/1/2001        2.826171
# 1   1/1/2002        1.586032
# 2   1/1/2003        2.270095
# 3   1/1/2004        2.677237
# 4   1/1/2005        3.392747
# 5   1/1/2006        3.225944
# 6   1/1/2007        2.852672
# 7   1/1/2008        3.839100
# 8   1/1/2009       -0.355546
# 9   1/1/2010        1.640043
# 10  1/1/2011        3.156842
# 11  1/1/2012        2.069337
# 12  1/1/2013        1.464833
# 13  1/1/2014        1.622223
# 14  1/1/2015        0.118627
# 15  1/1/2016        1.261583
# 16  1/1/2017        2.130110
# 17  1/1/2018        2.442583
# 18  1/1/2019        1.812210
# 19  1/1/2020        1.233584
# 20  1/1/2021        4.697859

# %%
inflation["Date"] = pd.to_datetime(inflation["DATE"])
inflation.head()
# Out:
#        DATE  FPCPITOTLZGUSA       Date
# 0  1/1/2001        2.826171 2001-01-01
# 1  1/1/2002        1.586032 2002-01-01
# 2  1/1/2003        2.270095 2003-01-01
# 3  1/1/2004        2.677237 2004-01-01
# 4  1/1/2005        3.392747 2005-01-01

# %%
inflation= inflation.drop(["DATE"],axis=1)
inflation
# Out:
#     FPCPITOTLZGUSA       Date
# 0         2.826171 2001-01-01
# 1         1.586032 2002-01-01
# 2         2.270095 2003-01-01
# 3         2.677237 2004-01-01
# 4         3.392747 2005-01-01
# 5         3.225944 2006-01-01
# 6         2.852672 2007-01-01
# 7         3.839100 2008-01-01
# 8        -0.355546 2009-01-01
# 9         1.640043 2010-01-01
# 10        3.156842 2011-01-01
# 11        2.069337 2012-01-01
# 12        1.464833 2013-01-01
# 13        1.622223 2014-01-01
# 14        0.118627 2015-01-01
# 15        1.261583 2016-01-01
# 16        2.130110 2017-01-01
# 17        2.442583 2018-01-01
# 18        1.812210 2019-01-01
# 19        1.233584 2020-01-01
# 20        4.697859 2021-01-01

# %%
inflation = pd.DataFrame(data=inflation, columns={'Date',"FPCPITOTLZGUSA"})
inflation
# Out:
#          Date  FPCPITOTLZGUSA
# 0  2001-01-01        2.826171
# 1  2002-01-01        1.586032
# 2  2003-01-01        2.270095
# 3  2004-01-01        2.677237
# 4  2005-01-01        3.392747
# 5  2006-01-01        3.225944
# 6  2007-01-01        2.852672
# 7  2008-01-01        3.839100
# 8  2009-01-01       -0.355546
# 9  2010-01-01        1.640043
# 10 2011-01-01        3.156842
# 11 2012-01-01        2.069337
# 12 2013-01-01        1.464833
# 13 2014-01-01        1.622223
# 14 2015-01-01        0.118627
# 15 2016-01-01        1.261583
# 16 2017-01-01        2.130110
# 17 2018-01-01        2.442583
# 18 2019-01-01        1.812210
# 19 2020-01-01        1.233584
# 20 2021-01-01        4.697859

# %%
inflation['Year'] = inflation['Date'].dt.year
inflation['Month'] = inflation['Date'].dt.month
inflation
# Out:
#          Date  FPCPITOTLZGUSA  Year  Month
# 0  2001-01-01        2.826171  2001      1
# 1  2002-01-01        1.586032  2002      1
# 2  2003-01-01        2.270095  2003      1
# 3  2004-01-01        2.677237  2004      1
# 4  2005-01-01        3.392747  2005      1
# 5  2006-01-01        3.225944  2006      1
# 6  2007-01-01        2.852672  2007      1
# 7  2008-01-01        3.839100  2008      1
# 8  2009-01-01       -0.355546  2009      1
# 9  2010-01-01        1.640043  2010      1
# 10 2011-01-01        3.156842  2011      1
# 11 2012-01-01        2.069337  2012      1
# 12 2013-01-01        1.464833  2013      1
# 13 2014-01-01        1.622223  2014      1
# 14 2015-01-01        0.118627  2015      1
# 15 2016-01-01        1.261583  2016      1
# 16 2017-01-01        2.130110  2017      1
# 17 2018-01-01        2.442583  2018      1
# 18 2019-01-01        1.812210  2019      1
# 19 2020-01-01        1.233584  2020      1
# 20 2021-01-01        4.697859  2021      1

# %%
inflation= inflation.drop(["Date"],axis=1)
inflation
# Out:
#     FPCPITOTLZGUSA  Year  Month
# 0         2.826171  2001      1
# 1         1.586032  2002      1
# 2         2.270095  2003      1
# 3         2.677237  2004      1
# 4         3.392747  2005      1
# 5         3.225944  2006      1
# 6         2.852672  2007      1
# 7         3.839100  2008      1
# 8        -0.355546  2009      1
# 9         1.640043  2010      1
# 10        3.156842  2011      1
# 11        2.069337  2012      1
# 12        1.464833  2013      1
# 13        1.622223  2014      1
# 14        0.118627  2015      1
# 15        1.261583  2016      1
# 16        2.130110  2017      1
# 17        2.442583  2018      1
# 18        1.812210  2019      1
# 19        1.233584  2020      1
# 20        4.697859  2021      1

# %%
inflation = pd.DataFrame(data=inflation, columns=['Year','Month',"FPCPITOTLZGUSA"])
inflation
# Out:
#     Year  Month  FPCPITOTLZGUSA
# 0   2001      1        2.826171
# 1   2002      1        1.586032
# 2   2003      1        2.270095
# 3   2004      1        2.677237
# 4   2005      1        3.392747
# 5   2006      1        3.225944
# 6   2007      1        2.852672
# 7   2008      1        3.839100
# 8   2009      1       -0.355546
# 9   2010      1        1.640043
# 10  2011      1        3.156842
# 11  2012      1        2.069337
# 12  2013      1        1.464833
# 13  2014      1        1.622223
# 14  2015      1        0.118627
# 15  2016      1        1.261583
# 16  2017      1        2.130110
# 17  2018      1        2.442583
# 18  2019      1        1.812210
# 19  2020      1        1.233584
# 20  2021      1        4.697859

# %%
inflation= inflation.rename(columns={"Year":"Year", "Month":"Month",
        "FPCPITOTLZGUSA":"inflation(%)"})
inflation
# Out:
#     Year  Month  inflation(%)
# 0   2001      1      2.826171
# 1   2002      1      1.586032
# 2   2003      1      2.270095
# 3   2004      1      2.677237
# 4   2005      1      3.392747
# 5   2006      1      3.225944
# 6   2007      1      2.852672
# 7   2008      1      3.839100
# 8   2009      1     -0.355546
# 9   2010      1      1.640043
# 10  2011      1      3.156842
# 11  2012      1      2.069337
# 12  2013      1      1.464833
# 13  2014      1      1.622223
# 14  2015      1      0.118627
# 15  2016      1      1.261583
# 16  2017      1      2.130110
# 17  2018      1      2.442583
# 18  2019      1      1.812210
# 19  2020      1      1.233584
# 20  2021      1      4.697859

# %%
inflation_yearly = inflation.drop(columns='Month')
inflation_yearly
# Out:
#     Year  inflation(%)
# 0   2001      2.826171
# 1   2002      1.586032
# 2   2003      2.270095
# 3   2004      2.677237
# 4   2005      3.392747
# 5   2006      3.225944
# 6   2007      2.852672
# 7   2008      3.839100
# 8   2009     -0.355546
# 9   2010      1.640043
# 10  2011      3.156842
# 11  2012      2.069337
# 12  2013      1.464833
# 13  2014      1.622223
# 14  2015      0.118627
# 15  2016      1.261583
# 16  2017      2.130110
# 17  2018      2.442583
# 18  2019      1.812210
# 19  2020      1.233584
# 20  2021      4.697859

# %%
df_merged_1 = inflation_yearly.merge(stock_to_GDP_percent_yearly, how='inner', on=['Year'])
df_merged_1
# Out:
#     Year  inflation(%)  stock_to_GDP(%)
# 0   2001      2.826171         132.1480
# 1   2002      1.586032         101.0791
# 2   2003      2.270095         124.5066
# 3   2004      2.677237         133.6506
# 4   2005      3.392747         130.4083
# 5   2006      3.225944         141.6542
# 6   2007      2.852672         137.8527
# 7   2008      3.839100          78.7766
# 8   2009     -0.355546         104.3488
# 9   2010      1.640043         115.2841
# 10  2011      3.156842         100.6313
# 11  2012      2.069337         115.2579
# 12  2013      1.464833         143.1937
# 13  2014      1.622223         150.2273
# 14  2015      0.118627         137.4445
# 15  2016      1.261583         145.9167
# 16  2017      2.130110         164.3593
# 17  2018      2.442583         147.6641
# 18  2019      1.812210         158.1229
# 19  2020      1.233584         194.4900

# %%
df_merged_2 = df_merged_1.merge(working_pop_yearly, how='inner', on=['Year'])
df_merged_2
# Out:
#     Year  inflation(%)  stock_to_GDP(%)  working_population
# 0   2001      2.826171         132.1480           181476647
# 1   2002      1.586032         101.0791           183792729
# 2   2003      2.270095         124.5066           186939817
# 3   2004      2.677237         133.6506           188763071
# 4   2005      3.392747         130.4083           191024953
# 5   2006      3.225944         141.6542           193219398
# 6   2007      2.852672         137.8527           195663562
# 7   2008      3.839100          78.7766           196691536
# 8   2009     -0.355546         104.3488           197897475
# 9   2010      1.640043         115.2841           199183839
# 10  2011      3.156842         100.6313           199962562
# 11  2012      2.069337         115.2579           201475828
# 12  2013      1.464833         143.1937           202327635
# 13  2014      1.622223         150.2273           203020518
# 14  2015      0.118627         137.4445           204334050
# 15  2016      1.261583         145.9167           205553963
# 16  2017      2.130110         164.3593           205570247
# 17  2018      2.442583         147.6641           206538862
# 18  2019      1.812210         158.1229           206309620
# 19  2020      1.233584         194.4900           205954426

# %%
df_merged = df_merged_2.merge(interest_rate_yearly, how='inner', on='Year')
df_merged
# Out:
#     Year  inflation(%)  stock_to_GDP(%)  working_population  Interest_Rate(%)
# 0   2001      2.826171         132.1480           181476647          3.410000
# 1   2002      1.586032         101.0791           183792729          1.173333
# 2   2003      2.270095         124.5066           186939817          2.104167
# 3   2004      2.677237         133.6506           188763071          2.395833
# 4   2005      3.392747         130.4083           191024953          4.250000
# 5   2006      3.225944         141.6542           193219398          6.020833
# 6   2007      2.852672         137.8527           195663562          5.791667
# 7   2008      3.839100          78.7766           196691536          2.166667
# 8   2009     -0.355546         104.3488           197897475          0.500000
# 9   2010      1.640043         115.2841           199183839          0.729167
# 10  2011      3.156842         100.6313           199962562          0.750000
# 11  2012      2.069337         115.2579           201475828          0.750000
# 12  2013      1.464833         143.1937           202327635          0.750000
# 13  2014      1.622223         150.2273           203020518          0.750000
# 14  2015      0.118627         137.4445           204334050          0.770833
# 15  2016      1.261583         145.9167           205553963          1.020833
# 16  2017      2.130110         164.3593           205570247          1.625000
# 17  2018      2.442583         147.6641           206538862          2.458333
# 18  2019      1.812210         158.1229           206309620          2.750000
# 19  2020      1.233584         194.4900           205954426          0.583333

# %%
df_merged.to_csv('Resources/cleaned_data/4_more_factors.csv', index=False)
